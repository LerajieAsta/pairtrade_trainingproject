# %% [markdown]
# ## 1. 數據管理與基礎預處理 (Data Pipeline)
#
# **執行功能**：建立 SQLite 資料庫連結並載入 S&P 500 歷史資料；計算對數轉換與均值回歸基礎檢驗；整合 VIX 指數並執行 1 日平移（Shift）以消除前視偏誤（Look-ahead Bias）；修正已下市股票成分以應對生存者偏誤。
#
# **參考文獻**：
# - Engle, R. F., & Granger, C. W. (1987). Co-integration and error correction.
# - Gatev, E., et al. (2006). Pairs Trading: Performance of a Relative-Value Arbitrage Rule.
#
# **參考重點與依據**：
# - **Engle-Granger 兩步法**：作為檢驗價差是否具備均值回歸特性的學術標準。
# - **生存者偏誤處理**：Gatev (2006) 提出應納入已下市股票資料，避免績效被過度高估。

# %%
import subprocess, sys
for pkg in ['statsmodels','plotly','ipywidgets','kaleido','scikit-learn','yfinance']:
    subprocess.check_call([sys.executable,'-m','pip','install',pkg,'-q'])
import warnings; warnings.filterwarnings('ignore')
import sqlite3, numpy as np, pandas as pd
import logging
from itertools import combinations
from statsmodels.tsa.stattools import coint
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display, HTML
pd.set_option('display.float_format','{:.4f}'.format)
import yfinance as yf
import time
import os
# print('套件導入完成。')

# %%
import os as _os

# ==========================================
# 🛑 全局模式切換開關 (True: 快速開發測試 / False: 論文最終完整回測)
# ==========================================
FAST_TEST_MODE = True

if FAST_TEST_MODE:
    print("🚀 啟動【快速測試模式】: 僅回測 2019-2022 年間之科技板塊。")
    # 縮短時間：涵蓋 2020 疫情崩盤與 2022 升息的壓力測試區間
    START_DATE = '2019-01-01'
    END_DATE = '2022-12-31'
    # 縮小股票池：僅測試單一板塊，運算量大幅減少
    TARGET_SECTOR = 'Information Technology'  
else:
    print("🐢 啟動【完整回測模式】: 回測 2000-2025 年間之全市場 S&P 500。")
    # 論文要求的全樣本時間
    START_DATE = '2000-01-01'
    END_DATE = '2025-12-31'
    # 測試全市場 (設為 None 代表不限制單一產業)
    TARGET_SECTOR = None  

# ==========================================
# 📊 共用策略參數 (兩種模式皆適用)
# ==========================================
DB_PATH           = r'..\data\sp500_data.db'
# 產業動態補齊開關與快取路徑
USE_DYNAMIC_SECTORS = True 
IMPUTED_SECTOR_PATH = r'..\data\imputed_sectors.csv'

# 視窗滾動參數
FORMATION_WINDOW = 252   # 形成期 (約一年)
TRADING_WINDOW = 126     # 交易期 (約半年)
ROLLING_WINDOW = 20      # 滾動步長 (約一個月)
MIN_HISTORY_DAYS  = 200

# 配對與統計檢定參數
MAX_PAIRS_PER_TRANCHE = 3  # 決定每個梯隊要執行的最大配對數 (可設為 1 或 3 或其他數字)
COINT_P_VALUE = 0.01     # 嚴格的共整合 p-value 門檻

# 交易執行與資金控管參數
TRANSACTION_COST = 0.0029 # 雙邊交易手續費 (0.29%)

INITIAL_CAPITAL = 30000  # 初始本金
CAPITAL_TRANCHES = 10       # 滾動視窗資金切割份數

# 確保快取檔案的上一層資料夾存在
os.makedirs(os.path.dirname(IMPUTED_SECTOR_PATH), exist_ok=True)
# Out:
# 🐢 啟動【完整回測模式】: 回測 2000-2025 年間之全市場 S&P 500。

# %%
def load_data_from_db(db_path, start_date, end_date):
    """Load price and sector data from SQLite."""
    conn = sqlite3.connect(db_path)
    price_queries = [
        (f"SELECT date, ticker, open, high, low, adj_close AS close, volume FROM daily_prices "
         f"WHERE date BETWEEN '{start_date}' AND '{end_date}' ORDER BY date"),
        (f"SELECT date, ticker, open, high, low, close, volume FROM stock_prices "
         f"WHERE date BETWEEN '{start_date}' AND '{end_date}' ORDER BY date"),
    ]
    prices_df = None
    for q in price_queries:
        try:
            prices_df = pd.read_sql_query(q, conn, parse_dates=['date'])
            if len(prices_df) > 0:
                print(f'Price rows: {len(prices_df):,}')
                break
        except Exception:
            continue
    if prices_df is None or len(prices_df) == 0:
        tbls = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", conn)
        conn.close()
        raise RuntimeError(f"No price table. Tables: {tbls['name'].tolist()}")
    sector_queries = [
        "SELECT ticker, sector FROM tickers",
        "SELECT ticker, sector FROM sp500_components GROUP BY ticker",
    ]
    sector_df = None
    for q in sector_queries:
        try:
            sector_df = pd.read_sql_query(q, conn)
            if len(sector_df) > 0:
                print(f'Sector rows: {len(sector_df):,}')
                break
        except Exception:
            continue
    conn.close()
    if sector_df is None or len(sector_df) == 0:
        print('WARNING: No sector table, using Unknown.')
        sector_df = pd.DataFrame({'ticker': prices_df['ticker'].unique(), 'sector': 'Unknown'})
        
    # [Mod] Mitigate Survivorship Bias: Check if delisted components exist
    max_date = prices_df['date'].max()
    max_dates = prices_df.groupby('ticker')['date'].max()
    delisted_count = (max_dates < max_date - pd.Timedelta(days=30)).sum()
    if delisted_count < 10:
        import logging
        logging.warning("STRICT RESEARCH LIMITATION: Database lacks historically delisted S&P 500 components. Survivorship Bias is present.")
        
    return prices_df, sector_df



def fix_unknown_sectors(sector_df, use_dynamic=True, save_path=r'data\imputed_sectors.csv'):
    """具備本機快取與全域開關控制的產業補齊模組"""
    # 1. 開關判斷：如果不使用動態補齊，直接原封不動回傳
    if not use_dynamic:
        print("不使用動態產業補齊，維持原始 Unknown 分類作為對照組。")
        return sector_df

    # 確保儲存的目錄 (data\) 存在
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    
    # 2. 快取讀取：如果已經抓過並存檔，直接載入
    if os.path.exists(save_path):
        print(f"從本機快取載入已補齊的產業分類: {save_path}")
        cached_df = pd.read_csv(save_path)
        update_df = cached_df.set_index('ticker')
        sector_df = sector_df.set_index('ticker')
        sector_df.update(update_df)
        return sector_df.reset_index()

    # 3. API 抓取：如果沒有快取，執行連線作業
    unknown_mask = sector_df['sector'] == 'Unknown'
    unknown_tickers = sector_df[unknown_mask]['ticker'].tolist()
    
    if not unknown_tickers:
        return sector_df

    print(f"找不到本機快取，正在透過 API 補齊 {len(unknown_tickers)} 檔 Unknown 股票的產業分類...")
    
    yf_logger = logging.getLogger('yfinance')
    original_level = yf_logger.level
    yf_logger.setLevel(logging.CRITICAL) 
    
    fixed_sectors = []
    
    for i, ticker in enumerate(unknown_tickers):
        try:
            info = yf.Ticker(ticker).info
            sector = info.get('sector', 'Unknown')
            fixed_sectors.append({'ticker': ticker, 'sector': sector})
            time.sleep(0.02) 
        except Exception:
            fixed_sectors.append({'ticker': ticker, 'sector': 'Unknown'})
            
        if (i + 1) % 50 == 0:
            print(f"已處理 {i + 1} / {len(unknown_tickers)}...")
            
    yf_logger.setLevel(original_level)
    
    # 4. 儲存快取：將剛抓下來的資料存成 CSV，下次就不用再抓了
    fetched_df = pd.DataFrame(fixed_sectors)
    fetched_df.to_csv(save_path, index=False)
    print(f"API 抓取完畢！已將動態產業分類永久儲存至: {save_path}")
    
    # 更新回原本的 DataFrame
    update_df = fetched_df.set_index('ticker')
    sector_df = sector_df.set_index('ticker')
    sector_df.update(update_df)
    sector_df = sector_df.reset_index()
    
    remaining = len(sector_df[sector_df['sector'] == 'Unknown'])
    print(f"補齊完成！剩餘真實無法識別(已下市)的 Unknown 股票數量: {remaining}")
    
    return sector_df

def preprocess_prices(prices_df, min_days=MIN_HISTORY_DAYS):
    """Pivot, forward-fill, drop sparse tickers."""
    pivot = prices_df.pivot_table(index='date', columns='ticker', values='close', aggfunc='last')
    pivot.index = pd.to_datetime(pivot.index)
    pivot.sort_index(inplace=True)
    pivot.ffill(limit=5, inplace=True)
    valid = pivot.columns[pivot.notna().sum() >= min_days]
    pivot = pivot[valid]
    print(f'Matrix: {len(pivot)} days x {len(pivot.columns)} tickers')

    # [Mod] Integrate Macroeconomic Indicator (VIX)
    import yfinance as yf
    print("Fetching VIX data...")
    try:
        vix_data = yf.download("^VIX", start=pivot.index.min(), end=pivot.index.max() + pd.Timedelta(days=1), progress=False)
        if isinstance(vix_data.columns, pd.MultiIndex):
            vix_close = vix_data['Close'].squeeze()
        else:
            vix_close = vix_data['Close']
        vix_df = pd.DataFrame({'VIX': vix_close})
        vix_df.index = pd.to_datetime(vix_df.index).tz_localize(None)
        # [Mod] Shift VIX by 1 day to completely prevent look-ahead bias
        vix_shifted = vix_df.shift(1)
        vix_aligned = vix_shifted.reindex(pivot.index).ffill()
        print("VIX feature matrix aligned.")
    except Exception as e:
        print(f"Error fetching VIX: {e}")
        vix_aligned = pd.DataFrame(index=pivot.index, columns=['VIX'])

    return pivot, vix_aligned

# %%
# 1. 從資料庫載入原始資料
prices_raw, sector_info = load_data_from_db(DB_PATH, START_DATE, END_DATE)

# 2. 攔截並補齊 Unknown 產業分類 (傳入全域開關與路徑)
sector_info = fix_unknown_sectors(
    sector_info, 
    use_dynamic=USE_DYNAMIC_SECTORS, 
    save_path=IMPUTED_SECTOR_PATH
)

# 3. 執行原有的價格矩陣轉換與 VIX 融合
price_pivot, vix_features = preprocess_prices(prices_raw)
sector_map = sector_info.set_index('ticker')['sector'].to_dict()

# 4. 顯示結果
print(pd.Series(sector_map).value_counts().head(10))
# Out:
# Price rows: 3,607,121
# Sector rows: 843
# 從本機快取載入已補齊的產業分類: ..\data\imputed_sectors.csv
# Matrix: 6539 days x 660 tickers
# Fetching VIX data...
# VIX feature matrix aligned.
# Unknown                   214
# Industrials                94
# Financials                 76
# Information Technology     71
# Health Care                60
# Consumer Discretionary     48
# Consumer Cyclical          37
# Real Estate                36
# Consumer Staples           36
# Energy                     35
# Name: count, dtype: int64

# %% [markdown]
# ## 2. 微觀統計特徵工程與品質過濾
#
# **執行功能**：計算股票個體的 Log Return、ATR、Z-Score、Hurst Exponent 與 Half-life（半衰期）。
#
# **參考文獻**：
# - Sarmento, M. S., & Horta, N. (2021). Pairs Trading via Unsupervised Learning.
#
# **參考重點與依據 (硬性篩選門檻)**：
# - **Hurst Exponent (H)**：僅保留 $H < 0.45$ 的股票，確保其具備強烈的均值回歸動能。
# - **Half-life (HL)**：僅保留 $HL < 126$ 天（約半年）的股票，確保回歸速度足以在有限時間內產生利潤。

# %%
from joblib import Parallel, delayed
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm


import numpy as np
import statsmodels.api as sm

def compute_hurst(ts):
    if len(ts) < 20: return 0.5
    lags = range(2, 20)
    # 確保不會遇到負數或零的警告
    with np.errstate(invalid='ignore', divide='ignore'):
        var_diff = [np.var(ts[lag:] - ts[:-lag]) for lag in lags]
    
    valid = [v > 0 and not np.isnan(v) for v in var_diff]
    if sum(valid) < 5: return 0.5
    
    poly = np.polyfit(np.log(np.array(lags)[valid]), np.log(np.array(var_diff)[valid]), 1)
    return poly[0] / 2.0
    
def compute_half_life(ts):
    z_lag = np.roll(ts, 1)
    z_lag[0] = 0
    z_ret = ts - z_lag
    z_ret[0] = 0
    z_lag2 = sm.add_constant(z_lag)
    try:
        res = sm.OLS(z_ret[1:], z_lag2[1:]).fit()
        hl = -np.log(2) / res.params[1]
        return hl if (hl > 0 and hl < 100) else 15.0
    except:
        return 15.0

def extract_micro_ts_features(ts):
    """提取微觀特徵，並確保回傳值數量與 DataFrame 欄位一致"""
    ticker = ts.name
    try:
        ts_vals = ts.dropna()
        if len(ts_vals) < 30:
            return tuple([ticker] + [np.nan] * 7) # 回傳 8 個元素
            
        # 1. 最近期對數報酬率
        log_ret = np.log(ts_vals / ts_vals.shift(1)).dropna()
        log_ret_latest = log_ret.iloc[-1]
        
        # 2. 波動率 (近似 ATR 概念：High-Low 或純粹標準差)
        atr_latest = ts_vals.rolling(14).std().iloc[-1]
        
        # 3. Z-Score (相對於 60 天均值)
        roll_mean = ts_vals.rolling(60).mean()
        roll_std = ts_vals.rolling(60).std()
        z_score_latest = ((ts_vals - roll_mean) / roll_std).iloc[-1]
        
        # 4. 成交量失衡 (假設目前無 Volume 欄位，先填 0 或結合 VIX)
        vol_imb_latest = 0.0 
        
        # 5. Hurst Exponent
        hurst = compute_hurst(ts_vals.values)
        
        # 6. Half-life (均值回歸半衰期)
        half_life = compute_half_life(ts_vals.values)
        
        # 7. ADF 檢定統計量
        try:
            adf_res = adfuller(ts_vals.values, maxlag=1, regression='c', autolag=None)
            adf_stat = adf_res[0]
        except:
            adf_stat = np.nan
            
        # [修復點] 完整回傳 8 個變數，對應特徵矩陣的欄位
        return ticker, log_ret_latest, atr_latest, z_score_latest, vol_imb_latest, hurst, half_life, adf_stat
        
    except Exception as e:
        # 發生錯誤時也必須回傳 8 個元素，避免 unpack 失敗
        return tuple([ticker] + [np.nan] * 7)

def feature_engineering_pipeline(panel_df, vix_series, n_jobs=-1, n_pca_components=3, scaler_in=None):
    """
    建構橫斷面特徵矩陣，直接準備好輸出給 DBSCAN 使用
    panel_df: 含有 open, high, low, close, volume 的 DataFrame
    vix_series: 此觀測窗口的 VIX 時間序列
    """
    print("啟動特徵工程 Pipeline...")
    
    # 確認 panel_df 是以 [date, ticker] 或是可以直接 pivot
    if not isinstance(panel_df.index, pd.MultiIndex):
        panel_df = panel_df.set_index(['date', 'ticker'])
        
    close_pivot = panel_df['close'].unstack(level='ticker')
    log_returns = np.log(close_pivot / close_pivot.shift(1)).fillna(0)
    
    # A. 將 Close 價格拉平計算全市場因子 (PCA) 與 相關性
    pca = PCA(n_components=n_pca_components)
    market_factors = pca.fit_transform(log_returns)
    reconstructed = pca.inverse_transform(market_factors)
    
    # 提取特有殘差 (PCA Residuals)
    pca_residuals = log_returns - reconstructed
    pca_res_latest = pca_residuals.iloc[-1]
    
    # 動態 Pearson Correlation (與 PCA 第一主成分計算短週期的共同波動性)
    mf_1_series = pd.Series(market_factors[:, 0], index=log_returns.index)
    market_corr = log_returns.apply(lambda x: x.iloc[-20:].corr(mf_1_series.iloc[-20:]))
    
    # B. 分配平行運算：迴圈切割給 CPU 計算各檔股票的微觀高強度特徵
    tickers = close_pivot.columns
    print(f"啟動多執行緒處理 {len(tickers)} 檔股票之時間序列與 ADF 微觀特徵...")
    
    # 將每個 ticker 的歷史 df 提早整理出來給 parallel
    # 避免在 function 裡面重新 filter 導致效率極差
    ticker_dfs = {t: panel_df.xs(t, level='ticker') for t in tickers if t in panel_df.index.get_level_values('ticker')}
    valid_tickers = list(ticker_dfs.keys())

    results = Parallel(n_jobs=n_jobs)(
        delayed(extract_micro_ts_features)(ticker_dfs[t]['close'].rename(t)) for t in valid_tickers
    )
    
    cols = ['ticker', 'Log_Ret', 'ATR', 'Z_Score', 'Vol_Imbalance', 'Hurst', 'Half_life', 'ADF_stat']
    features_df = pd.DataFrame([r for r in results if len(r) == 8], columns=cols).set_index('ticker') # 確保回傳長度相符
    features_df.columns = cols[1:]
    
    # C. 合併市場與總體經濟層面的特徵 (Macro Awareness)
    features_df['PCA_Res'] = pca_res_latest
    features_df['Market_Corr'] = market_corr
    features_df['VIX'] = vix_series.iloc[-1] if not vix_series.empty else np.nan
    
    features_df = features_df.dropna() # 清理計算中斷不穩定的死點
    
    # 1. 剔除 Hurst >= 0.5 的標的 及 確保回歸速度快於半年（約 126 個交易日），避免資金因長期未平倉而產生的機會成本。
    mask = (features_df['Hurst'] < 0.45) & (features_df['Half_life'] < 126)
    features_df = features_df[mask]
    
    # D. 嚴格的特徵標準化機制 (Standardization / Z-Score Scaling)
    if scaler_in is None:
        scaler = StandardScaler()
        fit_mode = True
    else:
        scaler = scaler_in
        fit_mode = False
    feature_columns = ['Log_Ret', 'ATR', 'Z_Score', 'Vol_Imbalance', 'Hurst', 'Half_life', 'ADF_stat', 'PCA_Res', 'Market_Corr', 'VIX']
    
    # 過濾出成功計算出特徵的欄位，防止錯誤
    valid_cols = [c for c in feature_columns if c in features_df.columns]
    
    if features_df.empty:
        print("⚠️ 警告：經過 Hurst < 0.45 與 Half_life < 126 篩選後，剩餘 0 檔股票。跳過此梯隊。")
        # 造一個假 scaler 以免 caller 崩潰
        if fit_mode:
            # np is already imported globally
            scaler.fit(np.zeros((1, len(valid_cols)))) 
        return pd.DataFrame(columns=valid_cols), scaler

    if fit_mode:
        std_matrix = scaler.fit_transform(features_df[valid_cols])
    else:
        std_matrix = scaler.transform(features_df[valid_cols])
    
    final_standardized_df = pd.DataFrame(std_matrix, index=features_df.index, columns=valid_cols)
    print(f"特徵矩陣建置完成！維度: {final_standardized_df.shape}")
    
    return final_standardized_df, scaler

# %% [markdown]
# ## 3. 動態分群與高獲利配對篩選
#
# **執行功能**：利用 PCA 提取特徵殘差，並執行 HDBSCAN 自動識別相似行為的股票群組；對同群組股票執行 Engle-Granger 共整合檢定與獲利空間校驗。
#
# **參考文獻**：
# - Sarmento & Horta (2021). Pairs Trading via Unsupervised Learning.
# - Campagnoli, T., et al. (2023). Dynamic pairs trading using clustering and reinforcement learning.
#
# **參考重點與依據 (硬性篩選門檻)**：
# - **年化過零率 (Zero-Crossing)**：在形成期內，價差穿越均值的次數必須 $\ge 12$ 次（平均每月至少一次），排除無波動的死水配對。
# - **獲利空間校驗**：價差標準差 ($\sigma_{spread}$) 必須 $\ge 2 	imes$ 雙邊交易成本 ($2 	imes 0.29\%$)，確保獲利能覆蓋摩擦成本。

# %%
from sklearn.cluster import HDBSCAN
from sklearn.metrics import silhouette_score, calinski_harabasz_score

def dynamic_hdbscan_clustering(features_df, sector_map, min_cluster_size=3):
    """
    HDBSCAN 動態分群 (板塊內層過濾)
    自動標記離群值 (Label = -1) 並輸出品質驗證指標。
    """
    features_df = features_df.copy()
    features_df['sector'] = features_df.index.map(lambda x: sector_map.get(x, 'Unknown'))
    feature_cols = [c for c in features_df.columns if c != 'sector']
    
    cluster_labels = pd.Series(index=features_df.index, dtype=int)
    cluster_labels[:] = -1
    
    global_offset = 0
    all_metrics = []
    
    for sector, group in features_df.groupby('sector'):
        if len(group) < min_cluster_size * 2:
            continue
            
        X = group[feature_cols].values
        
        # 實作: HDBSCAN 演算法
        clusterer = HDBSCAN(min_cluster_size=min_cluster_size, metric='euclidean', cluster_selection_method='eom')
        labels = clusterer.fit_predict(X)
        
        # 自動忽略 RuntimeWarning 發生的輪廓計算
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            valid_mask = labels != -1
            if len(set(labels[valid_mask])) > 1:
                try:
                    sil = silhouette_score(X[valid_mask], labels[valid_mask])
                    ch = calinski_harabasz_score(X[valid_mask], labels[valid_mask])
                    all_metrics.append({'sector': sector, 'silhouette': sil, 'calinski_harabasz': ch})
                except:
                    pass
            
        new_labels = []
        for l in labels:
            if l == -1:
                new_labels.append(-1)
            else:
                new_labels.append(l + global_offset)
                
        cluster_labels.loc[group.index] = new_labels
        if len(set(labels)) > 1:
            global_offset += max(labels) + 1
            
    if all_metrics:
        avg_sil = np.mean([x['silhouette'] for x in all_metrics])
        avg_ch = np.mean([x['calinski_harabasz'] for x in all_metrics])
        # print(f"  [Cluster Quality] Avg Silhouette: {avg_sil:.3f}, Avg CH Index: {avg_ch:.1f}")
        
    return cluster_labels


import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint

def test_single_coint(a, b, sector, price_window, p_threshold, min_len):
    series_a = price_window.get(a)
    series_b = price_window.get(b)
    
    if series_a is None or series_b is None:
        return None
        
    aligned = pd.concat([series_a, series_b], axis=1, join='inner').dropna()
    if len(aligned) < min_len:
        return None
        
    y = aligned.iloc[:, 0]
    x = aligned.iloc[:, 1]
    
    try:
        x_const = sm.add_constant(x)
        res = sm.OLS(y, x_const).fit()
        beta = res.params.iloc[1]
        
        score, pvalue, _ = coint(y, x, maxlag=1)
        
        # 強制過濾掉不合理 Beta，保護保證金不會因過度不對等爆倉
        if pvalue < p_threshold and 0.5 <= beta <= 2.0:
            return {
                'stock_a': a,
                'stock_b': b,
                'sector': sector,
                'p_value': pvalue,
                'beta': beta
            }
    except:
        pass
        
    return None
        
    aligned = pd.concat([series_a, series_b], axis=1, join='inner').dropna()
    if len(aligned) < min_len: return None
        
    y, x = aligned.iloc[:, 0], aligned.iloc[:, 1]
    
    try:
        x_const = sm.add_constant(x)
        res = sm.OLS(y, x_const).fit()
        beta = res.params.iloc[1]
        score, pvalue, _ = coint(y, x, maxlag=1)
        
        # 強制過濾掉不合理 Beta，保護保證金不會因過度不對等爆倉
        if pvalue < p_threshold and 0.5 <= beta <= 2.0:
            return {'stock_a': a, 'stock_b': b, 'sector': sector, 'p_value': pvalue, 'beta': beta}
    except:
        pass
    return None


def select_pairs_with_hdbscan(price_window, features_df, sector_map, top_ns, coint_pval=COINT_P_VALUE):
    if isinstance(top_ns, int):
        top_ns = [top_ns]
    """
    雙層過濾機制：
    第一層 HDBSCAN 動態群集
    第二層 Engle-Granger Cointegration
    """
    labels = dynamic_hdbscan_clustering(features_df, sector_map)
    unique_clusters = set(labels) - {-1}
    candidates = []
    
    for cid in unique_clusters:
        cluster_tickers = labels[labels == cid].index.tolist()
        if len(cluster_tickers) >= 2:
            s_map = features_df.loc[cluster_tickers[0], 'sector'] if 'sector' in features_df.columns else sector_map.get(cluster_tickers[0])
            for a, b in combinations(cluster_tickers, 2):
                candidates.append((a, b, s_map))
                
    if not candidates:
        return {n: [] for n in top_ns}
        
    print(f"完成排列組合，共產生 {len(candidates)} 組配對。前 5 組配對：")
    for i, c in enumerate(candidates[:5]):
        print(f"  {i+1}: {c[0]} vs {c[1]} (Sector: {c[2]})")
        
    min_len = len(price_window) * 0.8
    norm = price_window / price_window.iloc[0]
    
    coint_results = Parallel(n_jobs=-1, batch_size='auto')(
        delayed(test_single_coint)(a, b, sector, price_window, coint_pval, min_len)
        for a, b, sector in candidates
    )
    # 加入過零率門檻 (一年內至少過零 12 次，即每月平均一次)
    passed = [res for res in coint_results if res is not None]
    if not passed:
        return {n: [] for n in top_ns}
        
    print(f"P-value 檢定過濾後，剩餘 {len(passed)} 組配對。前 5 組配對：")
    for i, p in enumerate(passed[:5]):
        print(f"  {i+1}: {p['stock_a']} vs {p['stock_b']} (Beta: {p['beta']:.4f}, P-value: {p['p_value']:.4f})")
        
    for p in passed:
        try:
            # [修正點] 依照文獻對齊：Spread = Price_A - Beta * Price_B
            beta = p['beta']
            a_norm = norm[p['stock_a']]
            b_norm = norm[p['stock_b']]
            
            # 計算共整價差
            spread = a_norm - beta * b_norm
            
            spread_std = spread.std()
            p['spread_std'] = spread_std
            if spread_std < 0.0058: 
                p['ssd'] = np.inf 
                p['zero_cross'] = 0
                continue # 跳過後續計算，直接處理下一組

            # SSD 為價差的平方和
            p['ssd'] = (spread**2).sum()
            
            # 計算過零率 (均值回歸特徵)
            centered = spread - spread.mean()
            zero_crossings = ((centered.shift(1) * centered) < 0).sum()
            p['zero_cross'] = zero_crossings
            
            # 計算半衰期與獲利空間
            p['half_life'] = compute_half_life(spread.values)
            p['profit_space'] = spread.max() - spread.min()
        except:
            p['ssd'] = np.inf
            p['zero_cross'] = 0
            p['half_life'] = np.inf
            p['profit_space'] = 0
            
    # 依照 SSD 排序並選出 Top-N
    df_passed = pd.DataFrame(passed)
    if df_passed.empty:
        return {n: [] for n in top_ns}
        
    # 2. 強行過濾零交叉跟半衰期
    try:
        FORMATION_WINDOW = 252 # 取自全域變數或預設值
    except:
        FORMATION_WINDOW = 252 
        
    # 硬性篩選門檻
    df_passed = df_passed[(df_passed['zero_cross'] >= 12) & (df_passed['spread_std'] >= 0.0058)]
    if df_passed.empty:
        return {n: [] for n in top_ns}
        
    # 3. 綜合評分指標：(獲利空間 / 交易次數)
    df_passed['trade_count'] = df_passed['zero_cross'].replace(0, 1)
    df_passed['profit_per_trade'] = df_passed['profit_space'] / df_passed['trade_count']
    
    df_passed['ssd_rank'] = df_passed['ssd'].rank(ascending=True)
    df_passed['profit_rank'] = df_passed['profit_per_trade'].rank(ascending=False)
    df_passed['final_score'] = df_passed['ssd_rank'] + df_passed['profit_rank']
    
    df_passed = df_passed.sort_values('final_score')
    print(f"SSD 排序完成，前 5 組配對：")
    for i, (_, row) in enumerate(df_passed.head(5).iterrows()):
        print(f"  {i+1}: {row['stock_a']} vs {row['stock_b']} (SSD: {row['ssd']:.4f}, Beta: {row['beta']:.4f})")
        
    return {n: df_passed.head(n).to_dict('records') for n in top_ns}

# %% [markdown]
# ## 4. 強化學習 MDP 環境定義
#
# **執行功能**：封裝符合 Gymnasium 標準的 PairsTradingEnv；定義狀態空間（包含 Z-Score、VIX、Half-life）與離散動作空間（Long, Short, Flat）。
#
# **參考文獻**：
# - Brockman, G., et al. (2016). OpenAI Gym.
# - Lucarelli, G., et al. (2019). A deep reinforcement learning approach for automated cryptocurrency trading.
#
# **參考重點與依據**：
# - **混合獎勵設計**：結合增量損益、換倉摩擦、與針對最大回撤（MDD）的平方懲罰，解決金融回饋稀疏問題。

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

class PairsTradingEnv(gym.Env):
    metadata = {'render_modes': ['human']}

    def __init__(self, data_df, transaction_cost=0.0029, stop_loss_pct=-0.05, beta=1.0, ablation_vix=False):
        super(PairsTradingEnv, self).__init__()
        
        self.df = data_df.reset_index(drop=True)
        self.max_steps = len(self.df) - 1
        
        self.tc = transaction_cost
        self.stop_loss_pct = stop_loss_pct
        self.beta = beta
        self.ablation_vix = ablation_vix
        
        self.action_space = spaces.Discrete(3)
        self.obs_dim = 5 
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.obs_dim,), dtype=np.float32
        )
        
        self.current_step = 0
        self.current_pos = 0       
        self.entry_price_a = 0.0
        self.entry_price_b = 0.0
        self.total_reward = 0.0
        self.pnl_history = [0.0]
        
        self.cumulative_pnl = 0.0
        self.peak_pnl = 0.0
        
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.current_pos = 0
        self.entry_price_a = 0.0
        self.entry_price_b = 0.0
        self.total_reward = 0.0
        self.pnl_history = [0.0]
        
        self.cumulative_pnl = 0.0
        self.peak_pnl = 0.0
        return self._get_obs(), {}

    def _get_obs(self):
        row = self.df.iloc[self.current_step]
        unrealized_pnl = 0.0
        if self.current_pos != 0 and self.entry_price_a > 0:
            current_pa, current_pb = row['price_a'], row['price_b']
            if not pd.isna(current_pa) and not pd.isna(current_pb):
                unrealized_pnl = self.current_pos * (
                    ((current_pa - self.entry_price_a)/self.entry_price_a - 
                    self.beta * (current_pb - self.entry_price_b)/self.entry_price_b) / (1 + self.beta)
                )
        
        vix_val = 0.0 if self.ablation_vix else (row['vix'] if not pd.isna(row['vix']) else 20.0)
        zscore = row['z_score'] if not pd.isna(row['z_score']) else 0.0
        hl = row['half_life'] if not pd.isna(row['half_life']) else 15.0
        
        obs = np.array([zscore, vix_val, hl, float(self.current_pos), unrealized_pnl], dtype=np.float32)
        return obs

    def step(self, action):
        target_pos = 0
        if action == 1: target_pos = 1
        elif action == 2: target_pos = -1

        row = self.df.iloc[self.current_step]
        current_pa = row['price_a']
        current_pb = row['price_b']
        
        # [Survivorship Bias Fix] Detect Delisting
        is_delisted = pd.isna(current_pa) or pd.isna(current_pb) or current_pa <= 0 or current_pb <= 0
        if is_delisted:
            target_pos = 0
            
        step_pnl = 0.0
        unrealized_pnl = 0.0
        
        if self.current_pos != 0 and self.current_step > 0:
            prev_row = self.df.iloc[self.current_step - 1]
            prev_pa, prev_pb = prev_row['price_a'], prev_row['price_b']
            
            if is_delisted:
                unrealized_pnl = self.stop_loss_pct * 2.0
                step_pnl = unrealized_pnl
            else:
                try:
                    step_pnl = self.current_pos * (((current_pa - prev_pa) / prev_pa - self.beta * (current_pb - prev_pb) / prev_pb) / (1 + self.beta))
                    unrealized_pnl = self.current_pos * (((current_pa - self.entry_price_a) / self.entry_price_a - self.beta * (current_pb - self.entry_price_b) / self.entry_price_b) / (1 + self.beta))
                except:
                    step_pnl, unrealized_pnl = 0.0, 0.0

        forced_stop_loss = False
        if self.current_pos != 0 and (unrealized_pnl <= self.stop_loss_pct or is_delisted):
            forced_stop_loss = True
            target_pos = 0  
            
        trade_executed = 0
        if target_pos != self.current_pos:
            trades_needed = abs(target_pos - self.current_pos)
            trade_penalty = trades_needed * self.tc
            step_pnl -= trade_penalty
            if target_pos != 0:
                trade_executed = 1
            
            if target_pos != 0 and not is_delisted:
                self.entry_price_a = current_pa
                self.entry_price_b = current_pb
            else:
                self.entry_price_a, self.entry_price_b, unrealized_pnl = 0.0, 0.0, 0.0

        self.current_pos = target_pos
        self.pnl_history.append(step_pnl)
        
        # 累積資產高峰追蹤
        self.cumulative_pnl += step_pnl
        if self.cumulative_pnl > self.peak_pnl:
            self.peak_pnl = self.cumulative_pnl
        current_drawdown = self.peak_pnl - self.cumulative_pnl
        
        if len(self.pnl_history) > 10:
            rolling_std = np.std(self.pnl_history[-20:]) + 1e-6
            reward = step_pnl / rolling_std
        else:
            reward = step_pnl
            
        # 1. MDD 平方懲罰 (壓制無腦抱單)
        if current_drawdown > 0.02:
            reward -= (current_drawdown ** 2) * 100.0 
            
        # 2. 強力停損扣分 (-5.0) 
        if forced_stop_loss:
            reward -= 5.0
            
        self.current_step += 1
        terminated = bool(self.current_step >= self.max_steps)
        info = {
            'step_pnl': step_pnl, 'unrealized_pnl': unrealized_pnl,
            'forced_stop_loss': forced_stop_loss, 'current_position': self.current_pos,
            'delisted': is_delisted, 'trade_executed': trade_executed
        }
        return self._get_obs(), float(np.clip(reward, -10.0, 10.0)), terminated, False, info

    def render(self, mode='human'):
        pass

# %%
# =======================================================
# 驗證單元：環境冒煙測試 (Smoke Test with Dummy Data)
# =======================================================
print('🧪 Starting environment sanity check...')

# 建立模擬數據
dates = pd.date_range('2023-01-01', periods=100)
dummy_df = pd.DataFrame({
    'price_a': 100 + np.cumsum(np.random.normal(0, 1, 100)),
    'price_b': 100 + np.cumsum(np.random.normal(0, 1, 100)),
    'z_score': np.random.normal(0, 1, 100),
    'vix': 20 + np.random.normal(0, 2, 100),
    'half_life': [20.0] * 100
}, index=dates)

# 實例化環境
env_test = PairsTradingEnv(data_df=dummy_df, beta=1.0)
obs, info = env_test.reset()
print(f'✅ Reset successful. Initial Observation: {obs}')

# 執行一個隨機動作並檢查 reward
action = 1 # Long Spread
next_obs, reward, terminated, truncated, info = env_test.step(action)
print(f'✅ Step successful. Reward: {reward:.4f}, Position: {info["current_position"]}')
print('🚀 Sanity check passed! Environment is ready for RL training.')
# Out:
# 🧪 Starting environment sanity check...
# ✅ Reset successful. Initial Observation: [ 1.1671768 22.537558  20.         0.         0.       ]
# ✅ Step successful. Reward: -0.0029, Position: 1
# 🚀 Sanity check passed! Environment is ready for RL training.

# %% [markdown]
# ## 5. 滾動式推進分析與資產管理 (WFO Engine)
#
# **執行功能**：實作 Walk-Forward Optimization，嚴格切分訓練集與樣本外測試集；使用 PPO 演算法訓練代理人，並透過 Daily Portfolio Manager 執行多視窗滾動資金分配。
#
# **參考文獻**：
# - Schulman, J., et al. (2017). Proximal policy optimization algorithms.
#
# **參考重點與依據**：
# - **WFO 框架**：徹底防範前視偏誤，確保模型在時刻 $t$ 僅使用 $t$ 以前的資料。

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import gc
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv

# =========================================================================
# 執行時間紀錄參數
# =========================================================================
import time
from datetime import datetime

# 1. 記錄開始時間
start_wall_time = time.time()
start_timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"🚀 訓練開始時間: {start_timestamp}")

# --- 你的 DRL 訓練核心代碼 ---
# 例如: 
# model = PPO("MlpPolicy", env, verbose=1, ent_coef=0.01, n_steps=2048, ...)
# model.learn(total_timesteps=1000000) 
# -------------------------

# 2. 記錄結束時間並計算耗時
end_wall_time = time.time()
end_timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
total_seconds = end_wall_time - start_wall_time

# 3. 轉換格式 (小時:分鐘:秒)
hours = int(total_seconds // 3600)
minutes = int((total_seconds % 3600) // 60)
seconds = int(total_seconds % 60)

# =========================================================================
# 預處理函數
# =========================================================================

def safe_half_life(ts):
    if len(ts) < 30: return 15.0
    z_lag = np.roll(ts, 1)
    z_lag[0] = 0
    z_ret = ts - z_lag
    z_ret[0] = 0
    z_lag2 = sm.add_constant(z_lag)
    try:
        res = sm.OLS(z_ret[1:], z_lag2[1:]).fit()
        hl = -np.log(2) / res.params[1]
        return hl if (hl > 0 and hl < 100) else 15.0
    except:
        return 15.0

def prepare_rl_features(df, beta=1.0, z_window=60):
    df = df.copy()
    df['spread'] = df['price_a'] - beta * df['price_b']
    
    roll_mean = df['spread'].rolling(window=z_window).mean()
    roll_std = df['spread'].rolling(window=z_window).std()
    df['z_score'] = (df['spread'] - roll_mean) / roll_std
    
    hl_list = []
    last_valid_hl = 15.0 
    
    for i in range(len(df)):
        if i < z_window:
            hl_list.append(last_valid_hl)
        elif i % 20 == 0: 
            window_ts = df['spread'].iloc[i-z_window:i].dropna().values
            current_hl = safe_half_life(window_ts)
            hl_list.append(current_hl)
            last_valid_hl = current_hl
        else:
            hl_list.append(hl_list[-1])
            
    df['half_life'] = hl_list
    return df.ffill().fillna(0)

# =========================================================================
# WALK-FORWARD OPTIMIZATION: 日級資產累加引擎 (Daily Portfolio Manager)
# =========================================================================

# 確保 panel有雙重對齊
price_panel_df = prices_raw.copy()
if 'date' not in price_panel_df.index.names:
    price_panel_df.set_index(['date', 'ticker'], inplace=True)

# 系統級參數設定
ROLLING_STEP = ROLLING_WINDOW
TRANCHE_ALLOCATION = INITIAL_CAPITAL / CAPITAL_TRANCHES

print(f"🚀 啟動多視窗整合回測引擎 (Daily Portfolio Manager)")
print(f"📦 總資金: ${INITIAL_CAPITAL} | 單注: ${TRANCHE_ALLOCATION} | 梯隊滾動: {ROLLING_STEP}天")

all_dates = price_pivot.index
total_length = len(all_dates)

cash = INITIAL_CAPITAL
active_tranches = []
completed_tranches_count = 0
trade_frequencies = []
historical_dates = []
historical_portfolio_nav = []

failed_due_to_margin = False

# 每日推演主時間軸
for t in range(FORMATION_WINDOW, total_length):
    current_date = all_dates[t]
    
    # 1. 每日掃描，回收過期梯隊資金
    still_active = []
    for tr in active_tranches:
        if current_date >= tr['end_date']:
            final_nav = tr['series'].iloc[-1]
            cash += final_nav
            completed_tranches_count += 1
        else:
            still_active.append(tr)
    active_tranches = still_active

    # --- [新增] 準確計算每日整個系統的總淨值 ---
    daily_total_nav = cash
    for tr in active_tranches:
        latest_val = tr['series'].loc[:current_date]
        if not latest_val.empty:
            daily_total_nav += latest_val.iloc[-1]
            
    # --- [新增] 全系統破產底線檢查 ---
    if daily_total_nav < 1000.0:
        print(f"❌💥 破產警報！系統總資產 (${daily_total_nav:,.2f}) 已低於 $1000 最低維運標準。交易強制永久終止。")
        failed_due_to_margin = True
        break

    # 2. 定期滾動啟動新梯隊
    if (t - FORMATION_WINDOW) % ROLLING_STEP == 0:
        
        # --- [重點修改] 動態提撥總資產的 10% 建倉 ---
        # TRANCHE_ALLOCATION = INITIAL_CAPITAL * 0.10
        
        if cash < TRANCHE_ALLOCATION:
            # 這不是破產，只是這天現金卡在別的部位裡。不停止整個系統，只是這 20 天休息不開新單。
            print(f"⚠️ 現金水位 (${cash:,.2f}) 暫時不足以提撥 10% 資金 (${TRANCHE_ALLOCATION:,.2f})。新梯隊輪空！")
        else:
            train_start_date = all_dates[t - FORMATION_WINDOW].date()
            
        train_start_date = all_dates[t - FORMATION_WINDOW].date()
        train_end_date = all_dates[t].date()
        test_start_date = all_dates[t].date()
        test_end_idx = min(t + TRADING_WINDOW, total_length - 1)
        test_end_date = all_dates[test_end_idx].date()
        
        print(f"\n--- 🔄 新梯隊啟動 | 系統剩餘現金: ${cash:.2f} | 預計執行區間: {test_start_date} ~ {test_end_date} ---")
        
        train_panel = price_panel_df.loc[str(train_start_date):str(train_end_date)]
        train_pivot = price_pivot.loc[str(train_start_date):str(train_end_date)]
        train_vix = vix_features.loc[str(train_start_date):str(train_end_date)]['VIX']
        
        train_features_std, train_scaler = feature_engineering_pipeline(train_panel, train_vix)
        top_pairs_dict = select_pairs_with_hdbscan(train_pivot, train_features_std, sector_map, top_ns=[MAX_PAIRS_PER_TRANCHE])
        top_pairs = top_pairs_dict.get(MAX_PAIRS_PER_TRANCHE, [])
        
        if not top_pairs:
            print("⚠️ 無高品質共整配對，放棄建倉，資金輪空不使用。")
        else:
            cash -= TRANCHE_ALLOCATION 
            actual_pairs = top_pairs[:MAX_PAIRS_PER_TRANCHE]
            sub_allocation = TRANCHE_ALLOCATION / len(actual_pairs)
            
            print(f"✅ 款項抵扣 ${TRANCHE_ALLOCATION}，準備對 {len(actual_pairs)} 組配對執行預演(每組分配: ${sub_allocation:.2f})")
            
            tranche_nav_records = None
            total_trades_count = 0
            
            for p_idx, pair in enumerate(actual_pairs):
                    
                stk_a, stk_b, beta_coef = pair['stock_a'], pair['stock_b'], pair['beta']
                print(f"  - 組合 {p_idx+1}: {stk_a} vs {stk_b} (Beta: {beta_coef:.4f})")
                
                rl_train_raw = pd.DataFrame({'price_a': train_pivot[stk_a], 'price_b': train_pivot[stk_b], 'vix': train_vix}).dropna()
                rl_train_df = prepare_rl_features(rl_train_raw, beta_coef)
                env_train = PairsTradingEnv(data_df=rl_train_df, transaction_cost=TRANSACTION_COST, beta=beta_coef)
                vec_env_train = DummyVecEnv([lambda: env_train])
                
                model = PPO('MlpPolicy', vec_env_train, verbose=0, learning_rate=0.0003, gamma=0.99)
                model.learn(total_timesteps=30000)
                
                ext_test_start = pd.to_datetime(test_start_date) - pd.Timedelta(days=120)
                test_pivot = price_pivot.loc[ext_test_start:str(test_end_date)]
                test_vix = vix_features.loc[ext_test_start:str(test_end_date)]['VIX']
                
                rl_test_raw = pd.DataFrame({'price_a': test_pivot.get(stk_a, pd.Series(dtype=float)), 'price_b': test_pivot.get(stk_b, pd.Series(dtype=float)), 'vix': test_vix})
                rl_test_full = prepare_rl_features(rl_test_raw, beta_coef)
                actual_test_df = rl_test_full[rl_test_full.index >= pd.to_datetime(test_start_date)].reset_index()
                
                if len(actual_test_df) >= 10:
                    env_test = PairsTradingEnv(data_df=actual_test_df, transaction_cost=TRANSACTION_COST, beta=beta_coef)
                    vec_env_test = DummyVecEnv([lambda: env_test])
                    
                    obs = vec_env_test.reset()
                    dones = [False]
                    
                    sub_nav = sub_allocation
                    sub_records = [sub_nav]
                    tranche_dates = actual_test_df['date'].tolist()
                    
                    pair_trades_count = 0
                    while not dones[0]:
                        action, _ = model.predict(obs, deterministic=True)
                        obs, rewards, dones, infos = vec_env_test.step(action)
                        pair_trades_count += infos[0].get('trade_executed', 0)
                        total_trades_count += infos[0].get('trade_executed', 0)
                        
                        sub_nav += infos[0].get('step_pnl', 0.0) * sub_nav 
                        sub_records.append(sub_nav)
                            
                    if tranche_nav_records is None:
                        tranche_nav_records = np.array(sub_records)
                    else:
                        tranche_nav_records += np.array(sub_records)
                    
                        
                    
                    
                    pair_series = pd.Series(sub_records, index=tranche_dates)
                    pair_final_nav = pair_series.iloc[-1]
                    pair_ret = (pair_final_nav / sub_allocation) - 1.0
                    pair_peak = pair_series.cummax()
                    pair_mdd = ((pair_series - pair_peak) / pair_peak).min()
                    print(f"    ↳ [組合 {p_idx+1} 結算] 淨值: ${pair_final_nav:.2f} | 報酬率: {pair_ret*100:.2f}% | MDD: {pair_mdd*100:.2f}% | 交易次數: {pair_trades_count}")
                    
                    del env_test, vec_env_test
                
                    
                del env_train, vec_env_train, model
                gc.collect()
            
            if tranche_nav_records is not None:
                trade_frequencies.append(total_trades_count)
                daily_series = pd.Series(tranche_nav_records, index=tranche_dates)
                
                    
                # --- [介入點 A] ---
                final_nav = daily_series.iloc[-1]
                    
                ret = (final_nav / TRANCHE_ALLOCATION) - 1.0
                peak = daily_series.cummax()
                mdd = ((daily_series - peak) / peak).min()
                print(f"🎯 梯隊預演結算 | 最終淨值: ${final_nav:.2f} | 總報酬: {ret*100:.2f}% | MDD: {mdd*100:.2f}% | 交易次數: {total_trades_count}")
                
                active_tranches.append({'end_date': tranche_dates[-1], 'series': daily_series})

    # 3. 每日掃描：計算總資產 NAV_t
    historical_dates.append(current_date)
    historical_portfolio_nav.append(daily_total_nav)

print("\n🎉 回測迴圈結束！")
print(f"\n✅ 訓練結束時間: {end_timestamp}")
print(f"⏱️ 總共執行耗時: {hours} 小時 {minutes} 分 {seconds} 秒")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# 🚀 訓練開始時間: 2026-04-07 11:10:07
# 🚀 啟動多視窗整合回測引擎 (Daily Portfolio Manager)
# 📦 總資金: $30000 | 單注: $3000.0 | 梯隊滾動: 20天
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $30000.00 | 預計執行區間: 2001-01-02 ~ 2001-07-03 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 444 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (441, 10)
# 完成排列組合，共產生 947 組配對。前 5 組配對：
#   1: MHK vs KMX (Sector: Consumer Cyclical)
#   2: MHK vs BWA (Sector: Consumer Cyclical)
#   3: MHK vs VFC (Sector: Consumer Cyclical)
#   4: MHK vs WHR (Sector: Consumer Cyclical)
#   5: MHK vs LEG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 8 組配對。前 5 組配對：
#   1: CHD vs HRL (Beta: 1.1901, P-value: 0.0052)
#   2: APA vs BKR (Beta: 1.0842, P-value: 0.0040)
#   3: AJG vs PNC (Beta: 0.6299, P-value: 0.0014)
#   4: AXP vs AON (Beta: 0.5955, P-value: 0.0014)
#   5: AXP vs SPGI (Beta: 1.3897, P-value: 0.0001)
# SSD 排序完成，前 5 組配對：
#   1: JNJ vs SYK (SSD: 4.2775, Beta: 0.7312)
#   2: APA vs BKR (SSD: 13.8780, Beta: 1.0842)
#   3: CHD vs HRL (SSD: 20.6410, Beta: 1.1901)
#   4: AXP vs SPGI (SSD: 25.9725, Beta: 1.3897)
#   5: SPGI vs TROW (SSD: 52.5581, Beta: 1.2164)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: JNJ vs SYK (Beta: 0.7312)
#     ↳ [組合 1 結算] 淨值: $1034.14 | 報酬率: 3.41% | MDD: -12.45% | 交易次數: 1
#   - 組合 2: APA vs BKR (Beta: 1.0842)
#     ↳ [組合 2 結算] 淨值: $892.86 | 報酬率: -10.71% | MDD: -14.46% | 交易次數: 3
#   - 組合 3: CHD vs HRL (Beta: 1.1901)
#     ↳ [組合 3 結算] 淨值: $919.38 | 報酬率: -8.06% | MDD: -14.54% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $2846.38 | 總報酬: -5.12% | MDD: -11.04% | 交易次數: 6
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $27000.00 | 預計執行區間: 2001-01-31 ~ 2001-08-01 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 446 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (440, 10)
# 完成排列組合，共產生 1245 組配對。前 5 組配對：
#   1: BBY vs HAS (Sector: Consumer Discretionary)
#   2: BBY vs MAR (Sector: Consumer Discretionary)
#   3: BBY vs MGM (Sector: Consumer Discretionary)
#   4: BBY vs NKE (Sector: Consumer Discretionary)
#   5: BBY vs ORLY (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 23 組配對。前 5 組配對：
#   1: AXP vs FISV (Beta: 1.5987, P-value: 0.0068)
#   2: AXP vs MRSH (Beta: 0.6279, P-value: 0.0038)
#   3: BRK-B vs FITB (Beta: 1.1241, P-value: 0.0068)
#   4: BRK-B vs MET (Beta: 1.0313, P-value: 0.0032)
#   5: BLK vs BK (Beta: 1.0914, P-value: 0.0049)
# SSD 排序完成，前 5 組配對：
#   1: BRK-B vs MET (SSD: 0.0000, Beta: 1.0313)
#   2: PNC vs MET (SSD: 0.0000, Beta: 1.5077)
#   3: PFE vs EW (SSD: 0.0000, Beta: 0.8263)
#   4: BRK-B vs FITB (SSD: 4.2868, Beta: 1.1241)
#   5: HIG vs NTRS (SSD: 7.5519, Beta: 1.2606)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: BRK-B vs MET (Beta: 1.0313)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: PNC vs MET (Beta: 1.5077)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: PFE vs EW (Beta: 0.8263)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3000.00 | 總報酬: 0.00% | MDD: 0.00% | 交易次數: 0
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $24000.00 | 預計執行區間: 2001-03-01 ~ 2001-08-29 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 446 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (442, 10)
# 完成排列組合，共產生 1104 組配對。前 5 組配對：
#   1: T vs TKO (Sector: Communication Services)
#   2: T vs VZ (Sector: Communication Services)
#   3: T vs DIS (Sector: Communication Services)
#   4: T vs LUMN (Sector: Communication Services)
#   5: TKO vs VZ (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 17 組配對。前 5 組配對：
#   1: KMB vs TSN (Beta: 1.8633, P-value: 0.0077)
#   2: AON vs FISV (Beta: 1.9597, P-value: 0.0026)
#   3: BK vs HIG (Beta: 0.5236, P-value: 0.0005)
#   4: BK vs SPGI (Beta: 1.5638, P-value: 0.0086)
#   5: BK vs TRV (Beta: 0.7456, P-value: 0.0001)
# SSD 排序完成，前 5 組配對：
#   1: PNC vs MET (SSD: 0.0000, Beta: 1.5482)
#   2: BK vs TRV (SSD: 6.0345, Beta: 0.7456)
#   3: JNJ vs SYK (SSD: 9.0934, Beta: 0.6927)
#   4: CI vs MRK (SSD: 17.6600, Beta: 1.2975)
#   5: BK vs SPGI (SSD: 20.2335, Beta: 1.5638)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: PNC vs MET (Beta: 1.5482)
#     ↳ [組合 1 結算] 淨值: $1024.50 | 報酬率: 2.45% | MDD: -7.53% | 交易次數: 3
#   - 組合 2: BK vs TRV (Beta: 0.7456)
#     ↳ [組合 2 結算] 淨值: $861.75 | 報酬率: -13.82% | MDD: -17.18% | 交易次數: 3
#   - 組合 3: JNJ vs SYK (Beta: 0.6927)
#     ↳ [組合 3 結算] 淨值: $911.59 | 報酬率: -8.84% | MDD: -17.42% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $2797.85 | 總報酬: -6.74% | MDD: -9.00% | 交易次數: 8
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $21000.00 | 預計執行區間: 2001-03-29 ~ 2001-10-03 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 446 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (444, 10)
# 完成排列組合，共產生 1228 組配對。前 5 組配對：
#   1: MHK vs LEG (Sector: Consumer Cyclical)
#   2: MHK vs HOG (Sector: Consumer Cyclical)
#   3: LEG vs HOG (Sector: Consumer Cyclical)
#   4: WHR vs PVH (Sector: Consumer Cyclical)
#   5: WHR vs M (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 12 組配對。前 5 組配對：
#   1: KMB vs TSN (Beta: 1.8185, P-value: 0.0064)
#   2: CI vs MRK (Beta: 1.2069, P-value: 0.0090)
#   3: CI vs MTD (Beta: 0.7184, P-value: 0.0079)
#   4: MCK vs MTD (Beta: 0.8527, P-value: 0.0019)
#   5: MCK vs TMO (Beta: 1.3776, P-value: 0.0001)
# SSD 排序完成，前 5 組配對：
#   1: MSFT vs ZBRA (SSD: 2.2601, Beta: 0.6844)
#   2: CI vs MRK (SSD: 3.0776, Beta: 1.2069)
#   3: IT vs HPQ (SSD: 5.5407, Beta: 0.8299)
#   4: FFIV vs INTC (SSD: 15.9821, Beta: 0.8701)
#   5: MCK vs MTD (SSD: 32.3657, Beta: 0.8527)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: MSFT vs ZBRA (Beta: 0.6844)
#     ↳ [組合 1 結算] 淨值: $1010.11 | 報酬率: 1.01% | MDD: -13.68% | 交易次數: 3
#   - 組合 2: CI vs MRK (Beta: 1.2069)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: IT vs HPQ (Beta: 0.8299)
#     ↳ [組合 3 結算] 淨值: $771.59 | 報酬率: -22.84% | MDD: -24.50% | 交易次數: 3
# 🎯 梯隊預演結算 | 最終淨值: $2781.70 | 總報酬: -7.28% | MDD: -12.18% | 交易次數: 6
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $18000.00 | 預計執行區間: 2001-04-27 ~ 2001-10-31 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 446 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (445, 10)
# 完成排列組合，共產生 2037 組配對。前 5 組配對：
#   1: AZO vs DRI (Sector: Consumer Discretionary)
#   2: AZO vs EBAY (Sector: Consumer Discretionary)
#   3: AZO vs F (Sector: Consumer Discretionary)
#   4: AZO vs HD (Sector: Consumer Discretionary)
#   5: AZO vs MAR (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 14 組配對。前 5 組配對：
#   1: HD vs MGM (Beta: 1.2394, P-value: 0.0095)
#   2: AXP vs SCHW (Beta: 0.8125, P-value: 0.0036)
#   3: FITB vs KEY (Beta: 1.8111, P-value: 0.0081)
#   4: MRSH vs NTRS (Beta: 0.5958, P-value: 0.0018)
#   5: BK vs CB (Beta: 0.6953, P-value: 0.0002)
# SSD 排序完成，前 5 組配對：
#   1: ARE vs HST (SSD: 5.2379, Beta: 1.1101)
#   2: BK vs CB (SSD: 12.6728, Beta: 0.6953)
#   3: AXP vs SCHW (SSD: 13.9446, Beta: 0.8125)
#   4: BK vs FDS (SSD: 15.1361, Beta: 0.8761)
#   5: CMI vs FLS (SSD: 17.5398, Beta: 0.5467)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: ARE vs HST (Beta: 1.1101)
#     ↳ [組合 1 結算] 淨值: $889.90 | 報酬率: -11.01% | MDD: -17.74% | 交易次數: 3
#   - 組合 2: BK vs CB (Beta: 0.6953)
#     ↳ [組合 2 結算] 淨值: $851.64 | 報酬率: -14.84% | MDD: -18.29% | 交易次數: 9
#   - 組合 3: AXP vs SCHW (Beta: 0.8125)
#     ↳ [組合 3 結算] 淨值: $988.02 | 報酬率: -1.20% | MDD: -16.72% | 交易次數: 3
# 🎯 梯隊預演結算 | 最終淨值: $2729.57 | 總報酬: -9.01% | MDD: -13.79% | 交易次數: 15
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $15000.00 | 預計執行區間: 2001-05-25 ~ 2001-11-29 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 446 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (445, 10)
# 完成排列組合，共產生 1729 組配對。前 5 組配對：
#   1: BBY vs MGM (Sector: Consumer Discretionary)
#   2: BBY vs TPR (Sector: Consumer Discretionary)
#   3: MGM vs TPR (Sector: Consumer Discretionary)
#   4: LOW vs MAR (Sector: Consumer Discretionary)
#   5: LOW vs POOL (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 13 組配對。前 5 組配對：
#   1: AJG vs CB (Beta: 0.6817, P-value: 0.0011)
#   2: BLK vs BK (Beta: 1.0539, P-value: 0.0025)
#   3: BLK vs CB (Beta: 1.0977, P-value: 0.0024)
#   4: BK vs CB (Beta: 0.6652, P-value: 0.0003)
#   5: BK vs FDS (Beta: 0.7684, P-value: 0.0010)
# SSD 排序完成，前 5 組配對：
#   1: BK vs FDS (SSD: 1.7147, Beta: 0.7684)
#   2: BLK vs CB (SSD: 7.3136, Beta: 1.0977)
#   3: BK vs IVZ (SSD: 8.6050, Beta: 0.6140)
#   4: BK vs CB (SSD: 13.8703, Beta: 0.6652)
#   5: CB vs TRV (SSD: 31.6427, Beta: 0.7994)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: BK vs FDS (Beta: 0.7684)
#     ↳ [組合 1 結算] 淨值: $962.16 | 報酬率: -3.78% | MDD: -21.61% | 交易次數: 3
#   - 組合 2: BLK vs CB (Beta: 1.0977)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: BK vs IVZ (Beta: 0.6140)
#     ↳ [組合 3 結算] 淨值: $890.75 | 報酬率: -10.92% | MDD: -17.40% | 交易次數: 3
# 🎯 梯隊預演結算 | 最終淨值: $2852.91 | 總報酬: -4.90% | MDD: -10.97% | 交易次數: 6
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $12000.00 | 預計執行區間: 2001-06-25 ~ 2001-12-28 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 451 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (445, 10)
# 完成排列組合，共產生 1300 組配對。前 5 組配對：
#   1: BBY vs BKNG (Sector: Consumer Discretionary)
#   2: BBY vs CCL (Sector: Consumer Discretionary)
#   3: BBY vs DRI (Sector: Consumer Discretionary)
#   4: BBY vs DECK (Sector: Consumer Discretionary)
#   5: BBY vs DHI (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 8 組配對。前 5 組配對：
#   1: MMM vs PH (Beta: 1.1520, P-value: 0.0077)
#   2: HUBB vs ITW (Beta: 0.7801, P-value: 0.0064)
#   3: ARE vs WY (Beta: 0.6690, P-value: 0.0078)
#   4: REG vs SPG (Beta: 0.7365, P-value: 0.0054)
#   5: CMS vs D (Beta: 0.8350, P-value: 0.0001)
# SSD 排序完成，前 5 組配對：
#   1: MMM vs PH (SSD: 1.5078, Beta: 1.1520)
#   2: CMS vs EXC (SSD: 3.3588, Beta: 0.8487)
#   3: CMS vs D (SSD: 5.4597, Beta: 0.8350)
#   4: HUBB vs ITW (SSD: 8.6442, Beta: 0.7801)
#   5: CMS vs EVRG (SSD: 11.1504, Beta: 1.0731)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: MMM vs PH (Beta: 1.1520)
#     ↳ [組合 1 結算] 淨值: $952.88 | 報酬率: -4.71% | MDD: -8.64% | 交易次數: 2
#   - 組合 2: CMS vs EXC (Beta: 0.8487)
#     ↳ [組合 2 結算] 淨值: $936.66 | 報酬率: -6.33% | MDD: -13.72% | 交易次數: 2
#   - 組合 3: CMS vs D (Beta: 0.8350)
#     ↳ [組合 3 結算] 淨值: $889.33 | 報酬率: -11.07% | MDD: -17.83% | 交易次數: 5
# 🎯 梯隊預演結算 | 最終淨值: $2778.86 | 總報酬: -7.37% | MDD: -8.20% | 交易次數: 9
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $11846.38 | 預計執行區間: 2001-07-24 ~ 2002-01-29 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 452 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (445, 10)
# 完成排列組合，共產生 780 組配對。前 5 組配對：
#   1: MHK vs WHR (Sector: Consumer Cyclical)
#   2: MHK vs HRB (Sector: Consumer Cyclical)
#   3: MHK vs AN (Sector: Consumer Cyclical)
#   4: WHR vs HRB (Sector: Consumer Cyclical)
#   5: WHR vs AN (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 6 組配對。前 5 組配對：
#   1: HAS vs POOL (Beta: 0.8533, P-value: 0.0088)
#   2: COF vs FDS (Beta: 1.3318, P-value: 0.0059)
#   3: BMY vs CI (Beta: 0.5239, P-value: 0.0019)
#   4: BMY vs HUM (Beta: 0.9818, P-value: 0.0083)
#   5: LH vs MCK (Beta: 0.8850, P-value: 0.0088)
# SSD 排序完成，前 5 組配對：
#   1: HAS vs POOL (SSD: 1.6969, Beta: 0.8533)
#   2: CPT vs SPG (SSD: 1.8827, Beta: 1.1415)
#   3: COF vs FDS (SSD: 27.6223, Beta: 1.3318)
#   4: BMY vs HUM (SSD: 28.4090, Beta: 0.9818)
#   5: LH vs MCK (SSD: 36.8563, Beta: 0.8850)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: HAS vs POOL (Beta: 0.8533)
#     ↳ [組合 1 結算] 淨值: $974.42 | 報酬率: -2.56% | MDD: -13.51% | 交易次數: 2
#   - 組合 2: CPT vs SPG (Beta: 1.1415)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: COF vs FDS (Beta: 1.3318)
#     ↳ [組合 3 結算] 淨值: $761.60 | 報酬率: -23.84% | MDD: -23.84% | 交易次數: 8
# 🎯 梯隊預演結算 | 最終淨值: $2736.02 | 總報酬: -8.80% | MDD: -9.72% | 交易次數: 10
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $11846.38 | 預計執行區間: 2001-08-21 ~ 2002-02-27 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 454 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (446, 10)
# 完成排列組合，共產生 1024 組配對。前 5 組配對：
#   1: AMZN vs BBY (Sector: Consumer Discretionary)
#   2: AMZN vs CCL (Sector: Consumer Discretionary)
#   3: AMZN vs DRI (Sector: Consumer Discretionary)
#   4: AMZN vs DHI (Sector: Consumer Discretionary)
#   5: AMZN vs EBAY (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 4 組配對。前 5 組配對：
#   1: BK vs IVZ (Beta: 0.6830, P-value: 0.0039)
#   2: PLD vs SLG (Beta: 0.6554, P-value: 0.0059)
#   3: CPT vs SPG (Beta: 1.1874, P-value: 0.0095)
#   4: O vs REG (Beta: 0.5521, P-value: 0.0071)
# SSD 排序完成，前 5 組配對：
#   1: CPT vs SPG (SSD: 10.1133, Beta: 1.1874)
#   2: BK vs IVZ (SSD: 33.5011, Beta: 0.6830)
#   3: PLD vs SLG (SSD: 35.3499, Beta: 0.6554)
#   4: O vs REG (SSD: 90.7928, Beta: 0.5521)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: CPT vs SPG (Beta: 1.1874)
#     ↳ [組合 1 結算] 淨值: $955.09 | 報酬率: -4.49% | MDD: -10.41% | 交易次數: 1
#   - 組合 2: BK vs IVZ (Beta: 0.6830)
#     ↳ [組合 2 結算] 淨值: $989.29 | 報酬率: -1.07% | MDD: -11.49% | 交易次數: 4
#   - 組合 3: PLD vs SLG (Beta: 0.6554)
#     ↳ [組合 3 結算] 淨值: $991.66 | 報酬率: -0.83% | MDD: -1.59% | 交易次數: 3
# 🎯 梯隊預演結算 | 最終淨值: $2936.04 | 總報酬: -2.13% | MDD: -5.60% | 交易次數: 8
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $11644.23 | 預計執行區間: 2001-09-25 ~ 2002-03-27 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 454 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (450, 10)
# 完成排列組合，共產生 754 組配對。前 5 組配對：
#   1: CMCSA vs TKO (Sector: Communication Services)
#   2: CMCSA vs VZ (Sector: Communication Services)
#   3: CMCSA vs LUMN (Sector: Communication Services)
#   4: TKO vs VZ (Sector: Communication Services)
#   5: TKO vs LUMN (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 5 組配對。前 5 組配對：
#   1: MET vs WFC (Beta: 1.5386, P-value: 0.0021)
#   2: TFC vs USB (Beta: 0.9976, P-value: 0.0037)
#   3: BMY vs HUM (Beta: 0.9730, P-value: 0.0091)
#   4: CAH vs JNJ (Beta: 0.9868, P-value: 0.0036)
#   5: VNO vs SLG (Beta: 0.8304, P-value: 0.0009)
# SSD 排序完成，前 5 組配對：
#   1: CAH vs JNJ (SSD: 0.6231, Beta: 0.9868)
#   2: BMY vs HUM (SSD: 4.0260, Beta: 0.9730)
#   3: VNO vs SLG (SSD: 5.4941, Beta: 0.8304)
#   4: TFC vs USB (SSD: 14.2766, Beta: 0.9976)
#   5: MET vs WFC (SSD: 34.2718, Beta: 1.5386)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: CAH vs JNJ (Beta: 0.9868)
#     ↳ [組合 1 結算] 淨值: $888.50 | 報酬率: -11.15% | MDD: -13.83% | 交易次數: 6
#   - 組合 2: BMY vs HUM (Beta: 0.9730)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: VNO vs SLG (Beta: 0.8304)
#     ↳ [組合 3 結算] 淨值: $1023.42 | 報酬率: 2.34% | MDD: -3.37% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $2911.91 | 總報酬: -2.94% | MDD: -3.99% | 交易次數: 8
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $11425.93 | 預計執行區間: 2001-10-23 ~ 2002-04-25 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 455 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (452, 10)
# 完成排列組合，共產生 2353 組配對。前 5 組配對：
#   1: BWA vs VFC (Sector: Consumer Cyclical)
#   2: BWA vs WHR (Sector: Consumer Cyclical)
#   3: BWA vs PVH (Sector: Consumer Cyclical)
#   4: BWA vs LEG (Sector: Consumer Cyclical)
#   5: BWA vs HOG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 24 組配對。前 5 組配對：
#   1: M vs OI (Beta: 0.7584, P-value: 0.0079)
#   2: CB vs TRV (Beta: 0.8032, P-value: 0.0082)
#   3: IVZ vs MS (Beta: 0.5269, P-value: 0.0043)
#   4: MET vs WFC (Beta: 1.3133, P-value: 0.0028)
#   5: TFC vs USB (Beta: 0.8210, P-value: 0.0074)
# SSD 排序完成，前 5 組配對：
#   1: ARE vs SLG (SSD: 1.2912, Beta: 1.0947)
#   2: BMY vs HUM (SSD: 2.3562, Beta: 0.9671)
#   3: MTD vs TMO (SSD: 3.4036, Beta: 1.0133)
#   4: ADI vs TDY (SSD: 6.1139, Beta: 1.0423)
#   5: ITW vs PH (SSD: 7.6552, Beta: 0.6751)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: ARE vs SLG (Beta: 1.0947)
#     ↳ [組合 1 結算] 淨值: $1010.59 | 報酬率: 1.06% | MDD: -4.21% | 交易次數: 1
#   - 組合 2: BMY vs HUM (Beta: 0.9671)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: MTD vs TMO (Beta: 1.0133)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3010.59 | 總報酬: 0.35% | MDD: -1.41% | 交易次數: 1
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $11155.50 | 預計執行區間: 2001-11-20 ~ 2002-05-23 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 456 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (454, 10)
# 完成排列組合，共產生 469 組配對。前 5 組配對：
#   1: BWA vs PVH (Sector: Consumer Cyclical)
#   2: BWA vs MAT (Sector: Consumer Cyclical)
#   3: PVH vs MAT (Sector: Consumer Cyclical)
#   4: WHR vs LEG (Sector: Consumer Cyclical)
#   5: WHR vs HOG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 13 組配對。前 5 組配對：
#   1: MAR vs MGM (Beta: 1.2487, P-value: 0.0029)
#   2: MGM vs GRMN (Beta: 1.7748, P-value: 0.0097)
#   3: CRL vs MCK (Beta: 1.1796, P-value: 0.0085)
#   4: ADBE vs ADI (Beta: 1.1673, P-value: 0.0082)
#   5: ADI vs INTC (Beta: 1.4248, P-value: 0.0008)
# SSD 排序完成，前 5 組配對：
#   1: MGM vs GRMN (SSD: 0.0000, Beta: 1.7748)
#   2: ARE vs SLG (SSD: 1.2393, Beta: 0.9992)
#   3: MAR vs MGM (SSD: 2.8509, Beta: 1.2487)
#   4: CRL vs MCK (SSD: 3.0166, Beta: 1.1796)
#   5: ARE vs MAA (SSD: 3.9775, Beta: 1.0551)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: MGM vs GRMN (Beta: 1.7748)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: ARE vs SLG (Beta: 0.9992)
#     ↳ [組合 2 結算] 淨值: $950.77 | 報酬率: -4.92% | MDD: -5.97% | 交易次數: 2
#   - 組合 3: MAR vs MGM (Beta: 1.2487)
#     ↳ [組合 3 結算] 淨值: $1155.87 | 報酬率: 15.59% | MDD: -8.09% | 交易次數: 4
# 🎯 梯隊預演結算 | 最終淨值: $3106.64 | 總報酬: 3.55% | MDD: -2.66% | 交易次數: 6
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $11008.41 | 預計執行區間: 2001-12-19 ~ 2002-06-21 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 460 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (452, 10)
# 完成排列組合，共產生 813 組配對。前 5 組配對：
#   1: VFC vs PVH (Sector: Consumer Cyclical)
#   2: VFC vs LEG (Sector: Consumer Cyclical)
#   3: VFC vs M (Sector: Consumer Cyclical)
#   4: VFC vs GT (Sector: Consumer Cyclical)
#   5: VFC vs SIG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 21 組配對。前 5 組配對：
#   1: WHR vs HOG (Beta: 1.1007, P-value: 0.0046)
#   2: AXP vs COF (Beta: 0.6038, P-value: 0.0080)
#   3: AXP vs IVZ (Beta: 1.3308, P-value: 0.0015)
#   4: AXP vs JPM (Beta: 1.2987, P-value: 0.0005)
#   5: AXP vs MS (Beta: 0.6738, P-value: 0.0035)
# SSD 排序完成，前 5 組配對：
#   1: ARE vs SLG (SSD: 0.3721, Beta: 1.0331)
#   2: AXP vs NTRS (SSD: 1.6928, Beta: 0.8350)
#   3: AXP vs COF (SSD: 4.2149, Beta: 0.6038)
#   4: ATO vs NEE (SSD: 5.3397, Beta: 1.2755)
#   5: AXP vs MS (SSD: 6.2896, Beta: 0.6738)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: ARE vs SLG (Beta: 1.0331)
#     ↳ [組合 1 結算] 淨值: $1001.85 | 報酬率: 0.18% | MDD: -1.98% | 交易次數: 3
#   - 組合 2: AXP vs NTRS (Beta: 0.8350)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: AXP vs COF (Beta: 0.6038)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3001.85 | 總報酬: 0.06% | MDD: -0.66% | 交易次數: 3
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10787.27 | 預計執行區間: 2002-01-18 ~ 2002-07-22 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 460 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (454, 10)
# 完成排列組合，共產生 724 組配對。前 5 組配對：
#   1: BBY vs NKE (Sector: Consumer Discretionary)
#   2: BBY vs SBUX (Sector: Consumer Discretionary)
#   3: NKE vs SBUX (Sector: Consumer Discretionary)
#   4: GRMN vs MGM (Sector: Consumer Discretionary)
#   5: GRMN vs PHM (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 12 組配對。前 5 組配對：
#   1: AXP vs IVZ (Beta: 1.2016, P-value: 0.0007)
#   2: AXP vs NTRS (Beta: 0.8244, P-value: 0.0001)
#   3: IVZ vs MS (Beta: 0.5297, P-value: 0.0000)
#   4: IVZ vs NTRS (Beta: 0.6451, P-value: 0.0005)
#   5: MS vs NTRS (Beta: 1.0954, P-value: 0.0024)
# SSD 排序完成，前 5 組配對：
#   1: AXP vs NTRS (SSD: 1.4972, Beta: 0.8244)
#   2: AXP vs IVZ (SSD: 4.4332, Beta: 1.2016)
#   3: IBM vs ZBRA (SSD: 6.5845, Beta: 1.3857)
#   4: IVZ vs NTRS (SSD: 10.0930, Beta: 0.6451)
#   5: ARE vs FRT (SSD: 13.7374, Beta: 1.1306)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: AXP vs NTRS (Beta: 0.8244)
#     ↳ [組合 1 結算] 淨值: $815.03 | 報酬率: -18.50% | MDD: -23.04% | 交易次數: 4
#   - 組合 2: AXP vs IVZ (Beta: 1.2016)
#     ↳ [組合 2 結算] 淨值: $1330.65 | 報酬率: 33.07% | MDD: -8.76% | 交易次數: 1
#   - 組合 3: IBM vs ZBRA (Beta: 1.3857)
#     ↳ [組合 3 結算] 淨值: $929.43 | 報酬率: -7.06% | MDD: -17.46% | 交易次數: 5
# 🎯 梯隊預演結算 | 最終淨值: $3075.12 | 總報酬: 2.50% | MDD: -7.85% | 交易次數: 10
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10523.29 | 預計執行區間: 2002-02-19 ~ 2002-08-19 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 461 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (454, 10)
# 完成排列組合，共產生 1294 組配對。前 5 組配對：
#   1: APA vs BKR (Sector: Energy)
#   2: APA vs CVX (Sector: Energy)
#   3: APA vs COP (Sector: Energy)
#   4: APA vs XOM (Sector: Energy)
#   5: APA vs OXY (Sector: Energy)
# P-value 檢定過濾後，剩餘 16 組配對。前 5 組配對：
#   1: AXP vs IVZ (Beta: 1.2812, P-value: 0.0004)
#   2: AXP vs NTRS (Beta: 0.8312, P-value: 0.0068)
#   3: BAC vs FITB (Beta: 0.5607, P-value: 0.0050)
#   4: BAC vs GPN (Beta: 0.9179, P-value: 0.0004)
#   5: SCHW vs L (Beta: 0.6958, P-value: 0.0023)
# SSD 排序完成，前 5 組配對：
#   1: MS vs NTRS (SSD: 0.3937, Beta: 0.9130)
#   2: FRT vs VNO (SSD: 0.6929, Beta: 1.0826)
#   3: AXP vs NTRS (SSD: 3.5351, Beta: 0.8312)
#   4: MET vs RF (SSD: 4.0774, Beta: 0.9878)
#   5: SCHW vs L (SSD: 7.9187, Beta: 0.6958)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: MS vs NTRS (Beta: 0.9130)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: FRT vs VNO (Beta: 1.0826)
#     ↳ [組合 2 結算] 淨值: $895.05 | 報酬率: -10.49% | MDD: -10.87% | 交易次數: 3
#   - 組合 3: AXP vs NTRS (Beta: 0.8312)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $2895.05 | 總報酬: -3.50% | MDD: -3.63% | 交易次數: 3
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10459.34 | 預計執行區間: 2002-03-19 ~ 2002-09-17 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 461 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (458, 10)
# 完成排列組合，共產生 1085 組配對。前 5 組配對：
#   1: MHK vs BWA (Sector: Consumer Cyclical)
#   2: MHK vs SIG (Sector: Consumer Cyclical)
#   3: MHK vs BC (Sector: Consumer Cyclical)
#   4: BWA vs SIG (Sector: Consumer Cyclical)
#   5: BWA vs BC (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 16 組配對。前 5 組配對：
#   1: WHR vs HOG (Beta: 1.0526, P-value: 0.0041)
#   2: EOG vs EQT (Beta: 1.3682, P-value: 0.0047)
#   3: MMM vs DOV (Beta: 1.0996, P-value: 0.0098)
#   4: CHRW vs CTAS (Beta: 0.5143, P-value: 0.0020)
#   5: CAT vs NSC (Beta: 0.6193, P-value: 0.0021)
# SSD 排序完成，前 5 組配對：
#   1: FRT vs VNO (SSD: 0.4320, Beta: 1.0889)
#   2: MMM vs DOV (SSD: 0.5164, Beta: 1.0996)
#   3: AVB vs CPT (SSD: 0.6142, Beta: 0.8874)
#   4: WHR vs HOG (SSD: 3.3385, Beta: 1.0526)
#   5: CSCO vs MSFT (SSD: 9.6568, Beta: 0.5591)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: FRT vs VNO (Beta: 1.0889)
#     ↳ [組合 1 結算] 淨值: $898.62 | 報酬率: -10.14% | MDD: -10.14% | 交易次數: 4
#   - 組合 2: MMM vs DOV (Beta: 1.0996)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: AVB vs CPT (Beta: 0.8874)
#     ↳ [組合 3 結算] 淨值: $1015.04 | 報酬率: 1.50% | MDD: -4.96% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $2913.66 | 總報酬: -2.88% | MDD: -3.95% | 交易次數: 6
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10371.25 | 預計執行區間: 2002-04-17 ~ 2002-10-15 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 461 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (458, 10)
# 完成排列組合，共產生 541 組配對。前 5 組配對：
#   1: MHK vs SIG (Sector: Consumer Cyclical)
#   2: MHK vs URBN (Sector: Consumer Cyclical)
#   3: MHK vs KBH (Sector: Consumer Cyclical)
#   4: MHK vs BC (Sector: Consumer Cyclical)
#   5: SIG vs URBN (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 5 組配對。前 5 組配對：
#   1: LNC vs MBI (Beta: 1.0109, P-value: 0.0005)
#   2: CB vs MRSH (Beta: 1.1302, P-value: 0.0050)
#   3: MMM vs DOV (Beta: 1.0603, P-value: 0.0087)
#   4: ARE vs SLG (Beta: 1.1480, P-value: 0.0024)
#   5: FRT vs VNO (Beta: 1.1334, P-value: 0.0011)
# SSD 排序完成，前 5 組配對：
#   1: MMM vs DOV (SSD: 0.6087, Beta: 1.0603)
#   2: LNC vs MBI (SSD: 1.8808, Beta: 1.0109)
#   3: FRT vs VNO (SSD: 4.7182, Beta: 1.1334)
#   4: CB vs MRSH (SSD: 9.1553, Beta: 1.1302)
#   5: ARE vs SLG (SSD: 22.9928, Beta: 1.1480)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: MMM vs DOV (Beta: 1.0603)
#     ↳ [組合 1 結算] 淨值: $984.02 | 報酬率: -1.60% | MDD: -3.54% | 交易次數: 1
#   - 組合 2: LNC vs MBI (Beta: 1.0109)
#     ↳ [組合 2 結算] 淨值: $866.10 | 報酬率: -13.39% | MDD: -15.65% | 交易次數: 3
#   - 組合 3: FRT vs VNO (Beta: 1.1334)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $2850.12 | 總報酬: -5.00% | MDD: -5.75% | 交易次數: 4
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10381.84 | 預計執行區間: 2002-05-15 ~ 2002-11-12 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 461 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (459, 10)
# 完成排列組合，共產生 1524 組配對。前 5 組配對：
#   1: MHK vs KMX (Sector: Consumer Cyclical)
#   2: MHK vs SIG (Sector: Consumer Cyclical)
#   3: MHK vs BC (Sector: Consumer Cyclical)
#   4: MHK vs AAP (Sector: Consumer Cyclical)
#   5: KMX vs SIG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 16 組配對。前 5 組配對：
#   1: WHR vs HOG (Beta: 1.1318, P-value: 0.0004)
#   2: CLX vs MDLZ (Beta: 1.5084, P-value: 0.0031)
#   3: HP vs MUR (Beta: 0.9294, P-value: 0.0016)
#   4: IVZ vs NTRS (Beta: 0.6280, P-value: 0.0023)
#   5: PAYX vs LUV (Beta: 0.7653, P-value: 0.0055)
# SSD 排序完成，前 5 組配對：
#   1: CLX vs MDLZ (SSD: 0.0000, Beta: 1.5084)
#   2: WHR vs HOG (SSD: 0.8258, Beta: 1.1318)
#   3: PLD vs SPG (SSD: 1.4145, Beta: 0.8474)
#   4: ATO vs DTE (SSD: 3.0470, Beta: 0.8506)
#   5: IVZ vs NTRS (SSD: 16.0167, Beta: 0.6280)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: CLX vs MDLZ (Beta: 1.5084)
#     ↳ [組合 1 結算] 淨值: $960.52 | 報酬率: -3.95% | MDD: -10.14% | 交易次數: 2
#   - 組合 2: WHR vs HOG (Beta: 1.1318)
#     ↳ [組合 2 結算] 淨值: $751.39 | 報酬率: -24.86% | MDD: -25.25% | 交易次數: 5
#   - 組合 3: PLD vs SPG (Beta: 0.8474)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $2711.91 | 總報酬: -9.60% | MDD: -11.19% | 交易次數: 7
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10488.49 | 預計執行區間: 2002-06-13 ~ 2002-12-11 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 463 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (459, 10)
# 完成排列組合，共產生 1328 組配對。前 5 組配對：
#   1: T vs VZ (Sector: Communication Services)
#   2: T vs NYT (Sector: Communication Services)
#   3: VZ vs NYT (Sector: Communication Services)
#   4: TKO vs DIS (Sector: Communication Services)
#   5: TKO vs LUMN (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 9 組配對。前 5 組配對：
#   1: VFC vs PENN (Beta: 1.2113, P-value: 0.0000)
#   2: WHR vs HOG (Beta: 1.1113, P-value: 0.0004)
#   3: CLX vs PG (Beta: 0.8754, P-value: 0.0026)
#   4: ETN vs NDSN (Beta: 0.9566, P-value: 0.0073)
#   5: EMR vs MAS (Beta: 0.5799, P-value: 0.0099)
# SSD 排序完成，前 5 組配對：
#   1: ETN vs NDSN (SSD: 0.2539, Beta: 0.9566)
#   2: ADI vs CDNS (SSD: 1.1732, Beta: 0.8953)
#   3: CLX vs PG (SSD: 1.6912, Beta: 0.8754)
#   4: PLD vs SPG (SSD: 1.7302, Beta: 0.8994)
#   5: WHR vs HOG (SSD: 4.4934, Beta: 1.1113)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: ETN vs NDSN (Beta: 0.9566)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: ADI vs CDNS (Beta: 0.8953)
#     ↳ [組合 2 結算] 淨值: $1108.44 | 報酬率: 10.84% | MDD: -5.58% | 交易次數: 2
#   - 組合 3: CLX vs PG (Beta: 0.8754)
#     ↳ [組合 3 結算] 淨值: $1020.77 | 報酬率: 2.08% | MDD: -9.94% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $3129.21 | 總報酬: 4.31% | MDD: -3.41% | 交易次數: 4
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10490.34 | 預計執行區間: 2002-07-12 ~ 2003-01-10 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 464 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (459, 10)
# 完成排列組合，共產生 1398 組配對。前 5 組配對：
#   1: KMX vs BC (Sector: Consumer Cyclical)
#   2: KMX vs CCK (Sector: Consumer Cyclical)
#   3: BC vs CCK (Sector: Consumer Cyclical)
#   4: MHK vs BWA (Sector: Consumer Cyclical)
#   5: MHK vs VFC (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 9 組配對。前 5 組配對：
#   1: WHR vs HOG (Beta: 1.0968, P-value: 0.0005)
#   2: SBUX vs TPR (Beta: 0.6480, P-value: 0.0052)
#   3: NOV vs HP (Beta: 1.3324, P-value: 0.0002)
#   4: NOV vs MUR (Beta: 1.2486, P-value: 0.0016)
#   5: AMGN vs LLY (Beta: 1.1984, P-value: 0.0001)
# SSD 排序完成，前 5 組配對：
#   1: ADBE vs AMAT (SSD: 1.0818, Beta: 0.8471)
#   2: ATO vs SO (SSD: 2.2586, Beta: 0.7845)
#   3: WHR vs HOG (SSD: 3.4762, Beta: 1.0968)
#   4: EIX vs ETR (SSD: 4.8371, Beta: 1.0328)
#   5: AMGN vs LLY (SSD: 11.7720, Beta: 1.1984)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: ADBE vs AMAT (Beta: 0.8471)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: ATO vs SO (Beta: 0.7845)
#     ↳ [組合 2 結算] 淨值: $971.92 | 報酬率: -2.81% | MDD: -12.09% | 交易次數: 2
#   - 組合 3: WHR vs HOG (Beta: 1.0968)
#     ↳ [組合 3 結算] 淨值: $777.05 | 報酬率: -22.30% | MDD: -26.27% | 交易次數: 6
# 🎯 梯隊預演結算 | 最終淨值: $2748.96 | 總報酬: -8.37% | MDD: -10.69% | 交易次數: 8
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10565.46 | 預計執行區間: 2002-08-09 ~ 2003-02-10 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 464 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (459, 10)
# 完成排列組合，共產生 371 組配對。前 5 組配對：
#   1: CHD vs CAG (Sector: Consumer Staples)
#   2: CHD vs COST (Sector: Consumer Staples)
#   3: CHD vs DLTR (Sector: Consumer Staples)
#   4: CHD vs GIS (Sector: Consumer Staples)
#   5: CHD vs KMB (Sector: Consumer Staples)
# P-value 檢定過濾後，剩餘 6 組配對。前 5 組配對：
#   1: CB vs MRSH (Beta: 1.2658, P-value: 0.0067)
#   2: MAS vs PH (Beta: 0.5874, P-value: 0.0075)
#   3: PLD vs SPG (Beta: 0.8810, P-value: 0.0015)
#   4: ARE vs SLG (Beta: 1.2946, P-value: 0.0044)
#   5: WY vs VNO (Beta: 0.9999, P-value: 0.0038)
# SSD 排序完成，前 5 組配對：
#   1: PLD vs SPG (SSD: 1.5934, Beta: 0.8810)
#   2: WY vs VNO (SSD: 5.8773, Beta: 0.9999)
#   3: CB vs MRSH (SSD: 15.1822, Beta: 1.2658)
#   4: ATO vs D (SSD: 17.4620, Beta: 0.8268)
#   5: ARE vs SLG (SSD: 28.4254, Beta: 1.2946)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: PLD vs SPG (Beta: 0.8810)
#     ↳ [組合 1 結算] 淨值: $1015.17 | 報酬率: 1.52% | MDD: -1.27% | 交易次數: 1
#   - 組合 2: WY vs VNO (Beta: 0.9999)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: CB vs MRSH (Beta: 1.2658)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3015.17 | 總報酬: 0.51% | MDD: -0.42% | 交易次數: 1
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10460.51 | 預計執行區間: 2002-09-09 ~ 2003-03-11 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 464 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (461, 10)
# 完成排列組合，共產生 1400 組配對。前 5 組配對：
#   1: VFC vs PVH (Sector: Consumer Cyclical)
#   2: VFC vs MAT (Sector: Consumer Cyclical)
#   3: VFC vs SIG (Sector: Consumer Cyclical)
#   4: PVH vs MAT (Sector: Consumer Cyclical)
#   5: PVH vs SIG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 18 組配對。前 5 組配對：
#   1: BWA vs PENN (Beta: 1.5424, P-value: 0.0007)
#   2: HBAN vs KEY (Beta: 0.7652, P-value: 0.0039)
#   3: AMGN vs LLY (Beta: 1.0703, P-value: 0.0004)
#   4: EFX vs TT (Beta: 1.7345, P-value: 0.0051)
#   5: FDX vs PH (Beta: 1.9597, P-value: 0.0013)
# SSD 排序完成，前 5 組配對：
#   1: MAS vs ROK (SSD: 1.0154, Beta: 0.8482)
#   2: ITW vs MAS (SSD: 1.8912, Beta: 1.1766)
#   3: AMD vs NTAP (SSD: 5.2340, Beta: 0.8432)
#   4: AMGN vs LLY (SSD: 6.0607, Beta: 1.0703)
#   5: HBAN vs KEY (SSD: 16.1400, Beta: 0.7652)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: MAS vs ROK (Beta: 0.8482)
#     ↳ [組合 1 結算] 淨值: $805.10 | 報酬率: -19.49% | MDD: -23.60% | 交易次數: 4
#   - 組合 2: ITW vs MAS (Beta: 1.1766)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: AMD vs NTAP (Beta: 0.8432)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $2805.10 | 總報酬: -6.50% | MDD: -8.01% | 交易次數: 4
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10374.17 | 預計執行區間: 2002-10-07 ~ 2003-04-08 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 464 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (462, 10)
# 完成排列組合，共產生 1832 組配對。前 5 組配對：
#   1: DRI vs LEN (Sector: Consumer Discretionary)
#   2: DRI vs LOW (Sector: Consumer Discretionary)
#   3: DRI vs POOL (Sector: Consumer Discretionary)
#   4: DRI vs SBUX (Sector: Consumer Discretionary)
#   5: DRI vs TPR (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 17 組配對。前 5 組配對：
#   1: RF vs WFC (Beta: 1.0697, P-value: 0.0081)
#   2: AON vs TRV (Beta: 1.1258, P-value: 0.0003)
#   3: IVZ vs MS (Beta: 0.7966, P-value: 0.0006)
#   4: AMGN vs LLY (Beta: 1.0525, P-value: 0.0010)
#   5: CAH vs JNJ (Beta: 0.7457, P-value: 0.0048)
# SSD 排序完成，前 5 組配對：
#   1: RF vs WFC (SSD: 0.1501, Beta: 1.0697)
#   2: AMGN vs LLY (SSD: 0.6731, Beta: 1.0525)
#   3: ITW vs MAS (SSD: 1.0097, Beta: 1.0482)
#   4: CAH vs JNJ (SSD: 2.2382, Beta: 0.7457)
#   5: LIN vs MOS (SSD: 2.2511, Beta: 0.9731)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: RF vs WFC (Beta: 1.0697)
#     ↳ [組合 1 結算] 淨值: $942.88 | 報酬率: -5.71% | MDD: -10.01% | 交易次數: 2
#   - 組合 2: AMGN vs LLY (Beta: 1.0525)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: ITW vs MAS (Beta: 1.0482)
#     ↳ [組合 3 結算] 淨值: $987.99 | 報酬率: -1.20% | MDD: -9.11% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $2930.88 | 總報酬: -2.30% | MDD: -4.92% | 交易次數: 4
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10224.29 | 預計執行區間: 2002-11-04 ~ 2003-05-07 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 465 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (463, 10)
# 完成排列組合，共產生 2947 組配對。前 5 組配對：
#   1: BWA vs VFC (Sector: Consumer Cyclical)
#   2: BWA vs AN (Sector: Consumer Cyclical)
#   3: BWA vs URBN (Sector: Consumer Cyclical)
#   4: BWA vs FOSL (Sector: Consumer Cyclical)
#   5: BWA vs BC (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 24 組配對。前 5 組配對：
#   1: DLTR vs TSN (Beta: 1.6347, P-value: 0.0067)
#   2: BRK-B vs SPGI (Beta: 0.9789, P-value: 0.0084)
#   3: ERIE vs WFC (Beta: 1.0289, P-value: 0.0036)
#   4: HBAN vs WFC (Beta: 0.6769, P-value: 0.0073)
#   5: MS vs STT (Beta: 0.9827, P-value: 0.0002)
# SSD 排序完成，前 5 組配對：
#   1: EME vs AYI (SSD: 0.0000, Beta: 0.8448)
#   2: R vs AYI (SSD: 0.0000, Beta: 0.9464)
#   3: RF vs WFC (SSD: 1.3110, Beta: 1.0551)
#   4: ITW vs MAS (SSD: 1.7896, Beta: 0.9105)
#   5: ATO vs ETR (SSD: 2.1934, Beta: 0.8481)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: EME vs AYI (Beta: 0.8448)
#     ↳ [組合 1 結算] 淨值: $847.50 | 報酬率: -15.25% | MDD: -17.76% | 交易次數: 3
#   - 組合 2: R vs AYI (Beta: 0.9464)
#     ↳ [組合 2 結算] 淨值: $901.49 | 報酬率: -9.85% | MDD: -19.11% | 交易次數: 3
#   - 組合 3: RF vs WFC (Beta: 1.0551)
#     ↳ [組合 3 結算] 淨值: $1002.65 | 報酬率: 0.27% | MDD: -5.24% | 交易次數: 1
# 🎯 梯隊預演結算 | 最終淨值: $2751.64 | 總報酬: -8.28% | MDD: -11.71% | 交易次數: 7
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $9936.20 | 預計執行區間: 2002-12-03 ~ 2003-06-05 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 465 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (463, 10)
# 完成排列組合，共產生 2907 組配對。前 5 組配對：
#   1: MHK vs BWA (Sector: Consumer Cyclical)
#   2: MHK vs BBWI (Sector: Consumer Cyclical)
#   3: MHK vs VFC (Sector: Consumer Cyclical)
#   4: MHK vs PVH (Sector: Consumer Cyclical)
#   5: MHK vs PENN (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 30 組配對。前 5 組配對：
#   1: AJG vs MET (Beta: 1.0527, P-value: 0.0002)
#   2: EG vs FDS (Beta: 1.5048, P-value: 0.0014)
#   3: GPN vs MET (Beta: 0.5136, P-value: 0.0050)
#   4: MS vs STT (Beta: 0.9620, P-value: 0.0020)
#   5: PFG vs RF (Beta: 1.1555, P-value: 0.0088)
# SSD 排序完成，前 5 組配對：
#   1: MS vs STT (SSD: 0.3689, Beta: 0.9620)
#   2: AEE vs WEC (SSD: 1.7519, Beta: 1.0108)
#   3: ADBE vs AMAT (SSD: 1.7975, Beta: 1.0006)
#   4: LUV vs XRX (SSD: 2.5405, Beta: 0.9463)
#   5: SWK vs RHI (SSD: 2.6157, Beta: 1.0281)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: MS vs STT (Beta: 0.9620)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: AEE vs WEC (Beta: 1.0108)
#     ↳ [組合 2 結算] 淨值: $915.07 | 報酬率: -8.49% | MDD: -9.85% | 交易次數: 5
#   - 組合 3: ADBE vs AMAT (Beta: 1.0006)
#     ↳ [組合 3 結算] 淨值: $872.70 | 報酬率: -12.73% | MDD: -18.12% | 交易次數: 4
# 🎯 梯隊預演結算 | 最終淨值: $2787.76 | 總報酬: -7.07% | MDD: -8.89% | 交易次數: 9
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $10065.40 | 預計執行區間: 2003-01-02 ~ 2003-07-03 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 467 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (463, 10)
# 完成排列組合，共產生 699 組配對。前 5 組配對：
#   1: AZO vs CCL (Sector: Consumer Discretionary)
#   2: AZO vs LOW (Sector: Consumer Discretionary)
#   3: AZO vs RCL (Sector: Consumer Discretionary)
#   4: AZO vs SBUX (Sector: Consumer Discretionary)
#   5: CCL vs LOW (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 14 組配對。前 5 組配對：
#   1: HBAN vs KEY (Beta: 0.6374, P-value: 0.0045)
#   2: UNH vs UHS (Beta: 0.7886, P-value: 0.0059)
#   3: BA vs HON (Beta: 1.1118, P-value: 0.0084)
#   4: CAT vs SNA (Beta: 0.8769, P-value: 0.0080)
#   5: EME vs J (Beta: 0.7521, P-value: 0.0047)
# SSD 排序完成，前 5 組配對：
#   1: BA vs HON (SSD: 1.6825, Beta: 1.1118)
#   2: DD vs PKG (SSD: 4.3413, Beta: 1.0088)
#   3: CAT vs SNA (SSD: 7.1159, Beta: 0.8769)
#   4: JBL vs SNPS (SSD: 17.1977, Beta: 0.7216)
#   5: EMR vs PH (SSD: 27.5095, Beta: 0.6260)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: BA vs HON (Beta: 1.1118)
#     ↳ [組合 1 結算] 淨值: $918.32 | 報酬率: -8.17% | MDD: -11.99% | 交易次數: 2
#   - 組合 2: DD vs PKG (Beta: 1.0088)
#     ↳ [組合 2 結算] 淨值: $972.23 | 報酬率: -2.78% | MDD: -9.64% | 交易次數: 1
#   - 組合 3: CAT vs SNA (Beta: 0.8769)
#     ↳ [組合 3 結算] 淨值: $1071.97 | 報酬率: 7.20% | MDD: -7.33% | 交易次數: 1
# 🎯 梯隊預演結算 | 最終淨值: $2962.52 | 總報酬: -1.25% | MDD: -5.78% | 交易次數: 4
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $9814.37 | 預計執行區間: 2003-01-31 ~ 2003-08-01 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 467 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (464, 10)
# 完成排列組合，共產生 985 組配對。前 5 組配對：
#   1: MHK vs VFC (Sector: Consumer Cyclical)
#   2: MHK vs AAP (Sector: Consumer Cyclical)
#   3: MHK vs PVH (Sector: Consumer Cyclical)
#   4: MHK vs PENN (Sector: Consumer Cyclical)
#   5: MHK vs LEG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 10 組配對。前 5 組配對：
#   1: HBAN vs KEY (Beta: 0.5657, P-value: 0.0020)
#   2: GS vs MRSH (Beta: 1.6851, P-value: 0.0063)
#   3: GS vs STT (Beta: 1.2271, P-value: 0.0042)
#   4: MRSH vs MS (Beta: 0.6954, P-value: 0.0016)
#   5: ADI vs NTAP (Beta: 1.5560, P-value: 0.0092)
# SSD 排序完成，前 5 組配對：
#   1: PCG vs XEL (SSD: 3.3015, Beta: 1.1208)
#   2: GS vs STT (SSD: 6.8974, Beta: 1.2271)
#   3: CNP vs XEL (SSD: 21.0829, Beta: 0.5927)
#   4: ATO vs ETR (SSD: 30.7794, Beta: 0.7028)
#   5: MRSH vs MS (SSD: 39.9192, Beta: 0.6954)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: PCG vs XEL (Beta: 1.1208)
#     ↳ [組合 1 結算] 淨值: $809.67 | 報酬率: -19.03% | MDD: -19.06% | 交易次數: 5
#   - 組合 2: GS vs STT (Beta: 1.2271)
#     ↳ [組合 2 結算] 淨值: $963.48 | 報酬率: -3.65% | MDD: -12.97% | 交易次數: 4
#   - 組合 3: CNP vs XEL (Beta: 0.5927)
#     ↳ [組合 3 結算] 淨值: $923.16 | 報酬率: -7.68% | MDD: -35.19% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $2696.31 | 總報酬: -10.12% | MDD: -17.45% | 交易次數: 11
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $9829.54 | 預計執行區間: 2003-03-03 ~ 2003-08-29 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 467 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (464, 10)
# 完成排列組合，共產生 1296 組配對。前 5 組配對：
#   1: T vs VZ (Sector: Communication Services)
#   2: T vs LUMN (Sector: Communication Services)
#   3: VZ vs LUMN (Sector: Communication Services)
#   4: CMCSA vs EA (Sector: Communication Services)
#   5: CMCSA vs MTCH (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 18 組配對。前 5 組配對：
#   1: AXP vs FISV (Beta: 1.4172, P-value: 0.0089)
#   2: AXP vs MET (Beta: 1.2751, P-value: 0.0066)
#   3: AXP vs TROW (Beta: 1.6072, P-value: 0.0095)
#   4: AXP vs TRV (Beta: 0.5331, P-value: 0.0023)
#   5: AJG vs CINF (Beta: 1.2378, P-value: 0.0000)
# SSD 排序完成，前 5 組配對：
#   1: PRU vs USB (SSD: 0.5708, Beta: 0.9939)
#   2: PH vs SNA (SSD: 0.6833, Beta: 1.0225)
#   3: ORCL vs QCOM (SSD: 1.6559, Beta: 0.6516)
#   4: SNA vs TXT (SSD: 2.6662, Beta: 0.8268)
#   5: AXP vs MET (SSD: 5.3052, Beta: 1.2751)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: PRU vs USB (Beta: 0.9939)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: PH vs SNA (Beta: 1.0225)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: ORCL vs QCOM (Beta: 0.6516)
#     ↳ [組合 3 結算] 淨值: $1013.57 | 報酬率: 1.36% | MDD: -9.65% | 交易次數: 7
# 🎯 梯隊預演結算 | 最終淨值: $3013.57 | 總報酬: 0.45% | MDD: -3.42% | 交易次數: 7
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $9634.64 | 預計執行區間: 2003-03-31 ~ 2003-09-29 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 467 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (466, 10)
# 完成排列組合，共產生 1407 組配對。前 5 組配對：
#   1: MHK vs BWA (Sector: Consumer Cyclical)
#   2: MHK vs BBWI (Sector: Consumer Cyclical)
#   3: MHK vs WHR (Sector: Consumer Cyclical)
#   4: MHK vs LEG (Sector: Consumer Cyclical)
#   5: MHK vs HOG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 22 組配對。前 5 組配對：
#   1: MRK vs TMO (Beta: 1.1353, P-value: 0.0056)
#   2: CMI vs AYI (Beta: 0.7287, P-value: 0.0076)
#   3: DOV vs AYI (Beta: 1.4739, P-value: 0.0012)
#   4: EMR vs PH (Beta: 0.5361, P-value: 0.0045)
#   5: EMR vs SNA (Beta: 0.5938, P-value: 0.0030)
# SSD 排序完成，前 5 組配對：
#   1: CDNS vs TXN (SSD: 0.5451, Beta: 1.0041)
#   2: DD vs PKG (SSD: 0.9809, Beta: 0.9473)
#   3: MRK vs TMO (SSD: 1.5860, Beta: 1.1353)
#   4: CMI vs AYI (SSD: 1.9845, Beta: 0.7287)
#   5: ACN vs IT (SSD: 2.5772, Beta: 1.0423)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: CDNS vs TXN (Beta: 1.0041)
#     ↳ [組合 1 結算] 淨值: $1095.70 | 報酬率: 9.57% | MDD: -6.67% | 交易次數: 5
#   - 組合 2: DD vs PKG (Beta: 0.9473)
#     ↳ [組合 2 結算] 淨值: $922.57 | 報酬率: -7.74% | MDD: -11.71% | 交易次數: 3
#   - 組合 3: MRK vs TMO (Beta: 1.1353)
#     ↳ [組合 3 結算] 淨值: $1050.26 | 報酬率: 5.03% | MDD: -5.53% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $3068.52 | 總報酬: 2.28% | MDD: -3.35% | 交易次數: 10
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $9565.51 | 預計執行區間: 2003-04-29 ~ 2003-10-27 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 467 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (466, 10)
# 完成排列組合，共產生 823 組配對。前 5 組配對：
#   1: AMZN vs EBAY (Sector: Consumer Discretionary)
#   2: AMZN vs TPR (Sector: Consumer Discretionary)
#   3: EBAY vs TPR (Sector: Consumer Discretionary)
#   4: AZO vs BBY (Sector: Consumer Discretionary)
#   5: AZO vs BKNG (Sector: Consumer Discretionary)
# P-value 檢定過濾後，剩餘 10 組配對。前 5 組配對：
#   1: BKNG vs HD (Beta: 1.2830, P-value: 0.0087)
#   2: CHD vs HRL (Beta: 0.9048, P-value: 0.0029)
#   3: PG vs WMT (Beta: 0.8685, P-value: 0.0038)
#   4: DVN vs MUR (Beta: 1.0441, P-value: 0.0024)
#   5: MTB vs MET (Beta: 1.0897, P-value: 0.0048)
# SSD 排序完成，前 5 組配對：
#   1: DVN vs MUR (SSD: 0.7045, Beta: 1.0441)
#   2: MTB vs MET (SSD: 2.8047, Beta: 1.0897)
#   3: CMI vs EME (SSD: 6.2796, Beta: 0.6572)
#   4: PG vs WMT (SSD: 8.3794, Beta: 0.8685)
#   5: CHD vs HRL (SSD: 18.1901, Beta: 0.9048)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: DVN vs MUR (Beta: 1.0441)
#     ↳ [組合 1 結算] 淨值: $1112.17 | 報酬率: 11.22% | MDD: -5.67% | 交易次數: 2
#   - 組合 2: MTB vs MET (Beta: 1.0897)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: CMI vs EME (Beta: 0.6572)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3112.17 | 總報酬: 3.74% | MDD: -2.10% | 交易次數: 2
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $9317.15 | 預計執行區間: 2003-05-28 ~ 2003-11-24 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 467 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (466, 10)
# 完成排列組合，共產生 2824 組配對。前 5 組配對：
#   1: BBWI vs M (Sector: Consumer Cyclical)
#   2: BBWI vs URBN (Sector: Consumer Cyclical)
#   3: M vs URBN (Sector: Consumer Cyclical)
#   4: KMX vs WHR (Sector: Consumer Cyclical)
#   5: KMX vs PVH (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 34 組配對。前 5 組配對：
#   1: AFL vs BRO (Beta: 0.5626, P-value: 0.0014)
#   2: AXP vs PFG (Beta: 1.9016, P-value: 0.0005)
#   3: AJG vs CINF (Beta: 1.2080, P-value: 0.0000)
#   4: BRK-B vs CB (Beta: 1.1682, P-value: 0.0028)
#   5: BRK-B vs SPGI (Beta: 1.8761, P-value: 0.0000)
# SSD 排序完成，前 5 組配對：
#   1: CINF vs NDAQ (SSD: 0.0000, Beta: 0.7336)
#   2: PFG vs RF (SSD: 0.4061, Beta: 0.9922)
#   3: PRU vs USB (SSD: 0.4088, Beta: 1.0195)
#   4: EME vs ITT (SSD: 0.6259, Beta: 0.9301)
#   5: UPS vs ITT (SSD: 1.1267, Beta: 1.1809)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: CINF vs NDAQ (Beta: 0.7336)
#     ↳ [組合 1 結算] 淨值: $923.27 | 報酬率: -7.67% | MDD: -7.67% | 交易次數: 5
#   - 組合 2: PFG vs RF (Beta: 0.9922)
#     ↳ [組合 2 結算] 淨值: $970.09 | 報酬率: -2.99% | MDD: -8.22% | 交易次數: 2
#   - 組合 3: PRU vs USB (Beta: 1.0195)
#     ↳ [組合 3 結算] 淨值: $986.16 | 報酬率: -1.38% | MDD: -4.75% | 交易次數: 4
# 🎯 梯隊預演結算 | 最終淨值: $2879.53 | 總報酬: -4.02% | MDD: -5.32% | 交易次數: 11
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $9104.92 | 預計執行區間: 2003-06-25 ~ 2003-12-23 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 467 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (466, 10)
# 完成排列組合，共產生 2582 組配對。前 5 組配對：
#   1: PVH vs HRB (Sector: Consumer Cyclical)
#   2: PVH vs BC (Sector: Consumer Cyclical)
#   3: HRB vs BC (Sector: Consumer Cyclical)
#   4: WHR vs M (Sector: Consumer Cyclical)
#   5: WHR vs FOSL (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 34 組配對。前 5 組配對：
#   1: OXY vs MUR (Beta: 0.5986, P-value: 0.0079)
#   2: XOM vs HP (Beta: 0.7408, P-value: 0.0065)
#   3: AFL vs BRO (Beta: 0.5397, P-value: 0.0020)
#   4: AFL vs WRB (Beta: 0.8348, P-value: 0.0024)
#   5: AXP vs PFG (Beta: 1.9522, P-value: 0.0002)
# SSD 排序完成，前 5 組配對：
#   1: CINF vs NDAQ (SSD: 0.0000, Beta: 0.6330)
#   2: CINF vs KEY (SSD: 0.4259, Beta: 0.8889)
#   3: CINF vs WFC (SSD: 0.4796, Beta: 0.8773)
#   4: CINF vs HBAN (SSD: 0.7979, Beta: 0.7972)
#   5: CINF vs FISV (SSD: 1.4961, Beta: 0.8331)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: CINF vs NDAQ (Beta: 0.6330)
#     ↳ [組合 1 結算] 淨值: $963.41 | 報酬率: -3.66% | MDD: -15.30% | 交易次數: 4
#   - 組合 2: CINF vs KEY (Beta: 0.8889)
#     ↳ [組合 2 結算] 淨值: $994.30 | 報酬率: -0.57% | MDD: -6.02% | 交易次數: 1
#   - 組合 3: CINF vs WFC (Beta: 0.8773)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $2957.71 | 總報酬: -1.41% | MDD: -5.62% | 交易次數: 5
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $9067.44 | 預計執行區間: 2003-07-24 ~ 2004-01-23 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 468 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (466, 10)
# 完成排列組合，共產生 998 組配對。前 5 組配對：
#   1: T vs CMCSA (Sector: Communication Services)
#   2: T vs TKO (Sector: Communication Services)
#   3: T vs VZ (Sector: Communication Services)
#   4: T vs LUMN (Sector: Communication Services)
#   5: CMCSA vs TKO (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 13 組配對。前 5 組配對：
#   1: PVH vs URBN (Beta: 1.0698, P-value: 0.0051)
#   2: BBY vs TPR (Beta: 1.7083, P-value: 0.0027)
#   3: DVN vs MUR (Beta: 0.8867, P-value: 0.0056)
#   4: EQT vs OXY (Beta: 0.7415, P-value: 0.0099)
#   5: OXY vs MUR (Beta: 0.6204, P-value: 0.0019)
# SSD 排序完成，前 5 組配對：
#   1: AMAT vs INTC (SSD: 1.8131, Beta: 0.8180)
#   2: DVN vs MUR (SSD: 2.2716, Beta: 0.8867)
#   3: ATO vs EXC (SSD: 2.4161, Beta: 0.9447)
#   4: ADI vs ZBRA (SSD: 3.3386, Beta: 0.7918)
#   5: CINF vs RF (SSD: 3.5078, Beta: 0.8384)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: AMAT vs INTC (Beta: 0.8180)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: DVN vs MUR (Beta: 0.8867)
#     ↳ [組合 2 結算] 淨值: $1106.79 | 報酬率: 10.68% | MDD: -5.57% | 交易次數: 2
#   - 組合 3: ATO vs EXC (Beta: 0.9447)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3106.79 | 總報酬: 3.56% | MDD: -1.93% | 交易次數: 2
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $8763.75 | 預計執行區間: 2003-08-21 ~ 2004-02-23 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 468 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (467, 10)
# 完成排列組合，共產生 1019 組配對。前 5 組配對：
#   1: KMX vs BWA (Sector: Consumer Cyclical)
#   2: KMX vs WHR (Sector: Consumer Cyclical)
#   3: KMX vs SEE (Sector: Consumer Cyclical)
#   4: KMX vs M (Sector: Consumer Cyclical)
#   5: KMX vs AN (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 10 組配對。前 5 組配對：
#   1: F vs WSM (Beta: 0.5316, P-value: 0.0089)
#   2: CINF vs RF (Beta: 0.8469, P-value: 0.0003)
#   3: PFG vs RF (Beta: 1.5566, P-value: 0.0055)
#   4: ARE vs CCI (Beta: 0.5782, P-value: 0.0072)
#   5: ARE vs MAA (Beta: 1.0917, P-value: 0.0033)
# SSD 排序完成，前 5 組配對：
#   1: CINF vs RF (SSD: 4.0584, Beta: 0.8469)
#   2: ARE vs MAA (SSD: 5.7445, Beta: 1.0917)
#   3: ARE vs SPG (SSD: 8.2926, Beta: 0.7965)
#   4: AVB vs VNO (SSD: 17.2703, Beta: 1.1846)
#   5: ARE vs VTR (SSD: 18.4815, Beta: 1.2230)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: CINF vs RF (Beta: 0.8469)
#     ↳ [組合 1 結算] 淨值: $1024.00 | 報酬率: 2.40% | MDD: -4.55% | 交易次數: 1
#   - 組合 2: ARE vs MAA (Beta: 1.0917)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: ARE vs SPG (Beta: 0.7965)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3024.00 | 總報酬: 0.80% | MDD: -1.54% | 交易次數: 1
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $8777.32 | 預計執行區間: 2003-09-19 ~ 2004-03-22 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 468 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (467, 10)
# 完成排列組合，共產生 2474 組配對。前 5 組配對：
#   1: MHK vs BWA (Sector: Consumer Cyclical)
#   2: MHK vs BBWI (Sector: Consumer Cyclical)
#   3: MHK vs WHR (Sector: Consumer Cyclical)
#   4: MHK vs AAP (Sector: Consumer Cyclical)
#   5: MHK vs LEG (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 41 組配對。前 5 組配對：
#   1: AAP vs SIG (Beta: 0.8569, P-value: 0.0079)
#   2: M vs URBN (Beta: 1.2370, P-value: 0.0074)
#   3: SIG vs BC (Beta: 1.2740, P-value: 0.0060)
#   4: F vs WSM (Beta: 0.5878, P-value: 0.0003)
#   5: STZ vs HSY (Beta: 0.7974, P-value: 0.0000)
# SSD 排序完成，前 5 組配對：
#   1: HON vs RTX (SSD: 0.7331, Beta: 0.9921)
#   2: STZ vs HSY (SSD: 1.7136, Beta: 0.7974)
#   3: IEX vs ITW (SSD: 1.8238, Beta: 0.8725)
#   4: MSI vs ROP (SSD: 4.7643, Beta: 0.9364)
#   5: FIS vs MET (SSD: 5.1672, Beta: 0.8872)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: HON vs RTX (Beta: 0.9921)
#     ↳ [組合 1 結算] 淨值: $947.38 | 報酬率: -5.26% | MDD: -9.44% | 交易次數: 2
#   - 組合 2: STZ vs HSY (Beta: 0.7974)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: IEX vs ITW (Beta: 0.8725)
#     ↳ [組合 3 結算] 淨值: $928.17 | 報酬率: -7.18% | MDD: -14.04% | 交易次數: 4
# 🎯 梯隊預演結算 | 最終淨值: $2875.55 | 總報酬: -4.15% | MDD: -7.03% | 交易次數: 6
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $8845.84 | 預計執行區間: 2003-10-17 ~ 2004-04-20 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 469 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (468, 10)
# 完成排列組合，共產生 1810 組配對。前 5 組配對：
#   1: BWA vs AAP (Sector: Consumer Cyclical)
#   2: BWA vs M (Sector: Consumer Cyclical)
#   3: BWA vs AN (Sector: Consumer Cyclical)
#   4: BWA vs BC (Sector: Consumer Cyclical)
#   5: AAP vs M (Sector: Consumer Cyclical)
# P-value 檢定過濾後，剩餘 37 組配對。前 5 組配對：
#   1: F vs WSM (Beta: 0.5987, P-value: 0.0001)
#   2: CVX vs SLB (Beta: 0.5805, P-value: 0.0010)
#   3: CINF vs IVZ (Beta: 0.6361, P-value: 0.0090)
#   4: JKHY vs NTRS (Beta: 0.7625, P-value: 0.0051)
#   5: JPM vs MCO (Beta: 1.4153, P-value: 0.0054)
# SSD 排序完成，前 5 組配對：
#   1: EXC vs WEC (SSD: 1.0196, Beta: 1.0933)
#   2: ETR vs WEC (SSD: 1.2195, Beta: 1.1662)
#   3: REG vs MAC (SSD: 2.1558, Beta: 0.8823)
# ...
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 632 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (632, 10)
# 完成排列組合，共產生 1815 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs CHTR (Sector: Communication Services)
#   3: GOOGL vs CMCSA (Sector: Communication Services)
#   4: GOOGL vs EA (Sector: Communication Services)
#   5: GOOGL vs MTCH (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 7 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Beta: 0.9934, P-value: 0.0004)
#   2: FANG vs PSX (Beta: 0.6395, P-value: 0.0098)
#   3: COF vs NTRS (Beta: 1.9564, P-value: 0.0057)
#   4: CPT vs EQR (Beta: 1.8867, P-value: 0.0029)
#   5: EQR vs UDR (Beta: 1.5751, P-value: 0.0070)
# SSD 排序完成，前 5 組配對：
#   1: GOOGL vs GOOG (SSD: 0.0163, Beta: 0.9934)
#   2: DTE vs DUK (SSD: 10.7141, Beta: 0.8270)
#   3: CMS vs DTE (SSD: 45.8436, Beta: 0.6380)
#   4: EQR vs UDR (SSD: 111.4660, Beta: 1.5751)
#   5: FANG vs PSX (SSD: 116.6704, Beta: 0.6395)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: GOOGL vs GOOG (Beta: 0.9934)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: DTE vs DUK (Beta: 0.8270)
#     ↳ [組合 2 結算] 淨值: $999.85 | 報酬率: -0.02% | MDD: -0.58% | 交易次數: 2
#   - 組合 3: CMS vs DTE (Beta: 0.6380)
#     ↳ [組合 3 結算] 淨值: $1009.75 | 報酬率: 0.97% | MDD: -1.26% | 交易次數: 1
# 🎯 梯隊預演結算 | 最終淨值: $3009.60 | 總報酬: 0.32% | MDD: -0.42% | 交易次數: 3
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3889.55 | 預計執行區間: 2025-03-07 ~ 2025-09-08 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 633 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (632, 10)
# 完成排列組合，共產生 3940 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs CHTR (Sector: Communication Services)
#   3: GOOGL vs CMCSA (Sector: Communication Services)
#   4: GOOGL vs EA (Sector: Communication Services)
#   5: GOOGL vs MTCH (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 9 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Beta: 0.9938, P-value: 0.0020)
#   2: CFG vs TFC (Beta: 1.2677, P-value: 0.0001)
#   3: KEY vs RF (Beta: 0.6610, P-value: 0.0002)
#   4: UHS vs ZTS (Beta: 1.7522, P-value: 0.0020)
#   5: ALLE vs MAS (Beta: 1.6673, P-value: 0.0023)
# SSD 排序完成，前 5 組配對：
#   1: GOOGL vs GOOG (SSD: 0.0153, Beta: 0.9938)
#   2: ACN vs IT (SSD: 5.4638, Beta: 0.7305)
#   3: CFG vs TFC (SSD: 14.3614, Beta: 1.2677)
#   4: CAT vs HUBB (SSD: 27.8847, Beta: 0.7044)
#   5: KEY vs RF (SSD: 29.4488, Beta: 0.6610)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: GOOGL vs GOOG (Beta: 0.9938)
#     ↳ [組合 1 結算] 淨值: $980.16 | 報酬率: -1.98% | MDD: -2.04% | 交易次數: 3
#   - 組合 2: ACN vs IT (Beta: 0.7305)
#     ↳ [組合 2 結算] 淨值: $1095.99 | 報酬率: 9.60% | MDD: -2.75% | 交易次數: 3
#   - 組合 3: CFG vs TFC (Beta: 1.2677)
#     ↳ [組合 3 結算] 淨值: $1032.35 | 報酬率: 3.23% | MDD: -2.19% | 交易次數: 1
# 🎯 梯隊預演結算 | 最終淨值: $3108.49 | 總報酬: 3.62% | MDD: -0.97% | 交易次數: 7
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $4065.31 | 預計執行區間: 2025-04-04 ~ 2025-10-06 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 633 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (631, 10)
# 完成排列組合，共產生 5167 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs NFLX (Sector: Communication Services)
#   3: GOOGL vs NWSA (Sector: Communication Services)
#   4: GOOGL vs NWS (Sector: Communication Services)
#   5: GOOGL vs TKO (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 14 組配對。前 5 組配對：
#   1: ALL vs TRV (Beta: 0.7098, P-value: 0.0036)
#   2: CFG vs TFC (Beta: 1.2761, P-value: 0.0016)
#   3: KEY vs RF (Beta: 0.6742, P-value: 0.0001)
#   4: MS vs NTRS (Beta: 1.4628, P-value: 0.0006)
#   5: AME vs ROK (Beta: 0.5898, P-value: 0.0073)
# SSD 排序完成，前 5 組配對：
#   1: BR vs HWM (SSD: 6.3277, Beta: 0.7375)
#   2: CFG vs TFC (SSD: 16.7644, Beta: 1.2761)
#   3: GNRC vs JBHT (SSD: 21.8727, Beta: 1.0393)
#   4: KEY vs RF (SSD: 29.1211, Beta: 0.6742)
#   5: ALL vs TRV (SSD: 29.2709, Beta: 0.7098)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: BR vs HWM (Beta: 0.7375)
#     ↳ [組合 1 結算] 淨值: $1113.43 | 報酬率: 11.34% | MDD: -4.17% | 交易次數: 2
#   - 組合 2: CFG vs TFC (Beta: 1.2761)
#     ↳ [組合 2 結算] 淨值: $932.65 | 報酬率: -6.74% | MDD: -6.74% | 交易次數: 2
#   - 組合 3: GNRC vs JBHT (Beta: 1.0393)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3046.08 | 總報酬: 1.54% | MDD: -1.76% | 交易次數: 4
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $4018.35 | 預計執行區間: 2025-05-05 ~ 2025-11-03 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 633 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (632, 10)
# 完成排列組合，共產生 4522 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs CMCSA (Sector: Communication Services)
#   3: GOOGL vs MTCH (Sector: Communication Services)
#   4: GOOGL vs NWSA (Sector: Communication Services)
#   5: GOOGL vs NWS (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 15 組配對。前 5 組配對：
#   1: MS vs NTRS (Beta: 1.4107, P-value: 0.0021)
#   2: BIO vs ILMN (Beta: 1.5499, P-value: 0.0082)
#   3: MMM vs RTX (Beta: 1.6764, P-value: 0.0094)
#   4: AME vs EMR (Beta: 0.9713, P-value: 0.0023)
#   5: CHRW vs J (Beta: 0.7659, P-value: 0.0040)
# SSD 排序完成，前 5 組配對：
#   1: VRSK vs WM (SSD: 0.3706, Beta: 1.1400)
#   2: AME vs EMR (SSD: 1.0490, Beta: 0.9713)
#   3: GNRC vs JBHT (SSD: 3.5773, Beta: 1.2373)
#   4: ETN vs IEX (SSD: 34.9956, Beta: 1.5042)
#   5: ADI vs STX (SSD: 36.1161, Beta: 1.3124)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: VRSK vs WM (Beta: 1.1400)
#     ↳ [組合 1 結算] 淨值: $964.94 | 報酬率: -3.51% | MDD: -4.21% | 交易次數: 2
#   - 組合 2: AME vs EMR (Beta: 0.9713)
#     ↳ [組合 2 結算] 淨值: $948.94 | 報酬率: -5.11% | MDD: -13.47% | 交易次數: 3
#   - 組合 3: GNRC vs JBHT (Beta: 1.2373)
#     ↳ [組合 3 結算] 淨值: $975.03 | 報酬率: -2.50% | MDD: -18.63% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $2888.92 | 總報酬: -3.70% | MDD: -7.59% | 交易次數: 7
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3697.66 | 預計執行區間: 2025-06-03 ~ 2025-12-02 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 633 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (633, 10)
# 完成排列組合，共產生 2765 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs CHTR (Sector: Communication Services)
#   3: GOOGL vs CMCSA (Sector: Communication Services)
#   4: GOOGL vs EA (Sector: Communication Services)
#   5: GOOGL vs MTCH (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 13 組配對。前 5 組配對：
#   1: PG vs SYY (Beta: 0.9791, P-value: 0.0022)
#   2: ALL vs TRV (Beta: 0.6476, P-value: 0.0056)
#   3: ABT vs DGX (Beta: 0.8592, P-value: 0.0051)
#   4: ABBV vs JNJ (Beta: 1.6239, P-value: 0.0069)
#   5: DXCM vs EW (Beta: 1.8023, P-value: 0.0048)
# SSD 排序完成，前 5 組配對：
#   1: PG vs SYY (SSD: 0.2926, Beta: 0.9791)
#   2: AME vs EMR (SSD: 0.8089, Beta: 0.9672)
#   3: DELL vs MU (SSD: 1.5730, Beta: 0.7897)
#   4: VRSK vs WM (SSD: 1.7198, Beta: 1.1396)
#   5: DELL vs TXN (SSD: 5.1678, Beta: 0.8111)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: PG vs SYY (Beta: 0.9791)
#     ↳ [組合 1 結算] 淨值: $1076.36 | 報酬率: 7.64% | MDD: -5.13% | 交易次數: 1
#   - 組合 2: AME vs EMR (Beta: 0.9672)
#     ↳ [組合 2 結算] 淨值: $1002.03 | 報酬率: 0.20% | MDD: -1.27% | 交易次數: 2
#   - 組合 3: DELL vs MU (Beta: 0.7897)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3078.39 | 總報酬: 2.61% | MDD: -1.87% | 交易次數: 3
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3579.49 | 預計執行區間: 2025-07-02 ~ 2025-12-31 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 633 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (633, 10)
# 完成排列組合，共產生 4276 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs T (Sector: Communication Services)
#   3: GOOGL vs CHTR (Sector: Communication Services)
#   4: GOOGL vs CMCSA (Sector: Communication Services)
#   5: GOOGL vs EA (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 10 組配對。前 5 組配對：
#   1: DPZ vs TPR (Beta: 0.9393, P-value: 0.0024)
#   2: DPZ vs YUM (Beta: 1.5913, P-value: 0.0051)
#   3: PG vs TSN (Beta: 1.1335, P-value: 0.0026)
#   4: APA vs OXY (Beta: 0.6455, P-value: 0.0019)
#   5: ALL vs TRV (Beta: 0.5810, P-value: 0.0018)
# SSD 排序完成，前 5 組配對：
#   1: ABT vs DGX (SSD: 6.8033, Beta: 0.8586)
#   2: PG vs TSN (SSD: 7.3012, Beta: 1.1335)
#   3: PCAR vs FLS (SSD: 8.4554, Beta: 1.0687)
#   4: AEE vs ETR (SSD: 15.9119, Beta: 0.7435)
#   5: APA vs OXY (SSD: 20.9996, Beta: 0.6455)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: ABT vs DGX (Beta: 0.8586)
#     ↳ [組合 1 結算] 淨值: $1001.89 | 報酬率: 0.19% | MDD: -2.52% | 交易次數: 1
#   - 組合 2: PG vs TSN (Beta: 1.1335)
#     ↳ [組合 2 結算] 淨值: $1048.32 | 報酬率: 4.83% | MDD: -5.01% | 交易次數: 1
#   - 組合 3: PCAR vs FLS (Beta: 1.0687)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3050.21 | 總報酬: 1.67% | MDD: -1.68% | 交易次數: 2
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3574.53 | 預計執行區間: 2025-07-31 ~ 2025-12-31 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 633 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (633, 10)
# 完成排列組合，共產生 6265 組配對。前 5 組配對：
#   1: EA vs DV (Sector: Communication Services)
#   2: EA vs WB (Sector: Communication Services)
#   3: DV vs WB (Sector: Communication Services)
#   4: FOXA vs FOX (Sector: Communication Services)
#   5: FOXA vs NWS (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 25 組配對。前 5 組配對：
#   1: LOW vs POOL (Beta: 0.6189, P-value: 0.0085)
#   2: MGM vs TSCO (Beta: 0.7079, P-value: 0.0072)
#   3: BG vs CL (Beta: 1.3662, P-value: 0.0001)
#   4: BG vs MDLZ (Beta: 1.0724, P-value: 0.0031)
#   5: PG vs TSN (Beta: 1.2985, P-value: 0.0084)
# SSD 排序完成，前 5 組配對：
#   1: RSG vs VRSK (SSD: 0.8631, Beta: 1.1277)
#   2: CBOE vs ICE (SSD: 1.4736, Beta: 1.1150)
#   3: EMR vs R (SSD: 1.9130, Beta: 0.9604)
#   4: ADI vs MU (SSD: 2.4386, Beta: 0.9822)
#   5: PCAR vs FLS (SSD: 2.9273, Beta: 1.0848)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: RSG vs VRSK (Beta: 1.1277)
#     ↳ [組合 1 結算] 淨值: $1021.48 | 報酬率: 2.15% | MDD: -5.35% | 交易次數: 5
#   - 組合 2: CBOE vs ICE (Beta: 1.1150)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: EMR vs R (Beta: 0.9604)
#     ↳ [組合 3 結算] 淨值: $1076.43 | 報酬率: 7.64% | MDD: -9.11% | 交易次數: 1
# 🎯 梯隊預演結算 | 最終淨值: $3097.91 | 總報酬: 3.26% | MDD: -2.74% | 交易次數: 6
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3584.13 | 預計執行區間: 2025-08-28 ~ 2025-12-31 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 635 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (633, 10)
# 完成排列組合，共產生 4718 組配對。前 5 組配對：
#   1: FOXA vs FOX (Sector: Communication Services)
#   2: FOXA vs OMC (Sector: Communication Services)
#   3: FOX vs OMC (Sector: Communication Services)
#   4: EA vs NWS (Sector: Communication Services)
#   5: EA vs TMUS (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 15 組配對。前 5 組配對：
#   1: ALL vs SCHW (Beta: 0.5258, P-value: 0.0051)
#   2: ALL vs TRV (Beta: 0.5124, P-value: 0.0013)
#   3: ALL vs WRB (Beta: 0.9616, P-value: 0.0058)
#   4: BX vs TROW (Beta: 1.7675, P-value: 0.0058)
#   5: XYZ vs TROW (Beta: 1.2949, P-value: 0.0080)
# SSD 排序完成，前 5 組配對：
#   1: ALL vs WRB (SSD: 1.5207, Beta: 0.9616)
#   2: DAL vs FLS (SSD: 6.4225, Beta: 1.3387)
#   3: PODD vs LH (SSD: 10.9923, Beta: 1.5921)
#   4: XYZ vs TROW (SSD: 11.2359, Beta: 1.2949)
#   5: VNO vs MAC (SSD: 13.5421, Beta: 1.1958)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: ALL vs WRB (Beta: 0.9616)
#     ↳ [組合 1 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 2: DAL vs FLS (Beta: 1.3387)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: PODD vs LH (Beta: 1.5921)
#     ↳ [組合 3 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
# 🎯 梯隊預演結算 | 最終淨值: $3000.00 | 總報酬: 0.00% | MDD: 0.00% | 交易次數: 0
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3692.63 | 預計執行區間: 2025-09-26 ~ 2025-12-31 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 635 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (633, 10)
# 完成排列組合，共產生 7297 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs WBD (Sector: Communication Services)
#   3: GOOG vs WBD (Sector: Communication Services)
#   4: T vs CHTR (Sector: Communication Services)
#   5: T vs CMCSA (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 14 組配對。前 5 組配對：
#   1: DHI vs PHM (Beta: 1.4931, P-value: 0.0018)
#   2: ALL vs HIG (Beta: 0.8580, P-value: 0.0084)
#   3: ALL vs TRV (Beta: 0.5152, P-value: 0.0019)
#   4: APO vs PYPL (Beta: 1.5091, P-value: 0.0073)
#   5: AJG vs PGR (Beta: 1.2156, P-value: 0.0051)
# SSD 排序完成，前 5 組配對：
#   1: EPAM vs CRM (SSD: 2.2523, Beta: 0.9707)
#   2: AJG vs PGR (SSD: 4.7523, Beta: 1.2156)
#   3: ALL vs HIG (SSD: 5.3216, Beta: 0.8580)
#   4: XYZ vs TROW (SSD: 10.6800, Beta: 1.2848)
#   5: EFX vs FLR (SSD: 10.7634, Beta: 1.0235)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: EPAM vs CRM (Beta: 0.9707)
#     ↳ [組合 1 結算] 淨值: $1108.92 | 報酬率: 10.89% | MDD: -6.21% | 交易次數: 1
#   - 組合 2: AJG vs PGR (Beta: 1.2156)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: ALL vs HIG (Beta: 0.8580)
#     ↳ [組合 3 結算] 淨值: $1013.41 | 報酬率: 1.34% | MDD: -1.16% | 交易次數: 1
# 🎯 梯隊預演結算 | 最終淨值: $3122.32 | 總報酬: 4.08% | MDD: -2.09% | 交易次數: 2
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3738.70 | 預計執行區間: 2025-10-24 ~ 2025-12-31 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 638 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (634, 10)
# 完成排列組合，共產生 4289 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs WBD (Sector: Communication Services)
#   3: GOOG vs WBD (Sector: Communication Services)
#   4: T vs CMCSA (Sector: Communication Services)
#   5: T vs FOXA (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 30 組配對。前 5 組配對：
#   1: MTCH vs TGNA (Beta: 1.0200, P-value: 0.0079)
#   2: PSKY vs WB (Beta: 1.5674, P-value: 0.0049)
#   3: CCL vs TSCO (Beta: 0.9284, P-value: 0.0072)
#   4: DHI vs PHM (Beta: 1.4513, P-value: 0.0026)
#   5: EXPE vs GRMN (Beta: 0.9551, P-value: 0.0014)
# SSD 排序完成，前 5 組配對：
#   1: MCD vs YUM (SSD: 0.8191, Beta: 0.8546)
#   2: MAS vs PCAR (SSD: 0.8847, Beta: 0.8330)
#   3: PCAR vs FLS (SSD: 1.3561, Beta: 1.0242)
#   4: TECH vs MRK (SSD: 3.4180, Beta: 1.1420)
#   5: AME vs TXT (SSD: 5.1847, Beta: 1.0586)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: MCD vs YUM (Beta: 0.8546)
#     ↳ [組合 1 結算] 淨值: $956.87 | 報酬率: -4.31% | MDD: -4.31% | 交易次數: 5
#   - 組合 2: MAS vs PCAR (Beta: 0.8330)
#     ↳ [組合 2 結算] 淨值: $1034.82 | 報酬率: 3.48% | MDD: -2.39% | 交易次數: 1
#   - 組合 3: PCAR vs FLS (Beta: 1.0242)
#     ↳ [組合 3 結算] 淨值: $957.11 | 報酬率: -4.29% | MDD: -4.33% | 交易次數: 1
# 🎯 梯隊預演結算 | 最終淨值: $2948.80 | 總報酬: -1.71% | MDD: -2.75% | 交易次數: 7
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3627.62 | 預計執行區間: 2025-11-21 ~ 2025-12-31 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 639 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (635, 10)
# 完成排列組合，共產生 3400 組配對。前 5 組配對：
#   1: LYV vs META (Sector: Communication Services)
#   2: LYV vs TKO (Sector: Communication Services)
#   3: LYV vs DIS (Sector: Communication Services)
#   4: LYV vs WB (Sector: Communication Services)
#   5: META vs TKO (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 9 組配對。前 5 組配對：
#   1: LOW vs WSM (Beta: 0.6255, P-value: 0.0062)
#   2: COP vs EOG (Beta: 0.6320, P-value: 0.0072)
#   3: COP vs OXY (Beta: 1.4483, P-value: 0.0004)
#   4: KEY vs RF (Beta: 0.6368, P-value: 0.0002)
#   5: DHR vs MRK (Beta: 1.9997, P-value: 0.0011)
# SSD 排序完成，前 5 組配對：
#   1: LOW vs WSM (SSD: 3.5535, Beta: 0.6255)
#   2: FDX vs JBHT (SSD: 16.9880, Beta: 1.2777)
#   3: COP vs EOG (SSD: 20.2861, Beta: 0.6320)
#   4: KEY vs RF (SSD: 29.5319, Beta: 0.6368)
#   5: DGX vs STE (SSD: 34.4793, Beta: 0.6487)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: LOW vs WSM (Beta: 0.6255)
#     ↳ [組合 1 結算] 淨值: $980.86 | 報酬率: -1.91% | MDD: -3.85% | 交易次數: 1
#   - 組合 2: FDX vs JBHT (Beta: 1.2777)
#     ↳ [組合 2 結算] 淨值: $1000.00 | 報酬率: 0.00% | MDD: 0.00% | 交易次數: 0
#   - 組合 3: COP vs EOG (Beta: 0.6320)
#     ↳ [組合 3 結算] 淨值: $938.81 | 報酬率: -6.12% | MDD: -6.92% | 交易次數: 2
# 🎯 梯隊預演結算 | 最終淨值: $2919.67 | 總報酬: -2.68% | MDD: -3.03% | 交易次數: 3
#
# --- 🔄 新梯隊啟動 | 系統剩餘現金: $3706.02 | 預計執行區間: 2025-12-22 ~ 2025-12-31 ---
# 啟動特徵工程 Pipeline...
# 啟動多執行緒處理 639 檔股票之時間序列與 ADF 微觀特徵...
# 特徵矩陣建置完成！維度: (635, 10)
# 完成排列組合，共產生 2719 組配對。前 5 組配對：
#   1: GOOGL vs GOOG (Sector: Communication Services)
#   2: GOOGL vs EA (Sector: Communication Services)
#   3: GOOGL vs NYT (Sector: Communication Services)
#   4: GOOG vs EA (Sector: Communication Services)
#   5: GOOG vs NYT (Sector: Communication Services)
# P-value 檢定過濾後，剩餘 6 組配對。前 5 組配對：
#   1: T vs VZ (Beta: 0.9894, P-value: 0.0079)
#   2: EBAY vs GPC (Beta: 1.2251, P-value: 0.0012)
#   3: CL vs KVUE (Beta: 1.7642, P-value: 0.0028)
#   4: DGX vs STE (Beta: 0.5826, P-value: 0.0099)
#   5: AOS vs VLTO (Beta: 0.5755, P-value: 0.0038)
# SSD 排序完成，前 5 組配對：
#   1: T vs VZ (SSD: 5.2146, Beta: 0.9894)
#   2: EBAY vs GPC (SSD: 7.1778, Beta: 1.2251)
#   3: AOS vs VLTO (SSD: 45.4938, Beta: 0.5755)
#   4: DGX vs STE (SSD: 63.3166, Beta: 0.5826)
#   5: ITW vs VLTO (SSD: 111.5757, Beta: 1.6443)
# ✅ 款項抵扣 $3000.0，準備對 3 組配對執行預演(每組分配: $1000.00)
#   - 組合 1: T vs VZ (Beta: 0.9894)
#   - 組合 2: EBAY vs GPC (Beta: 1.2251)
#   - 組合 3: AOS vs VLTO (Beta: 0.5755)
#
# 🎉 回測迴圈結束！

# %% [markdown]
# ## 6. 基準對標與績效可視化
#
# **執行功能**：與 S&P 500 (SPY) 買入持有策略進行對標分析；繪製累積報酬曲線、最大回撤圖，並計算全期間統計指標。
#
# **參考重點**：
# - 遵循元智大學 (YZU) 資管系論文圖表規範與 APA 引用格式。

# %%
# =========================================================================
# 可視化的自動跟隨更新 (對標 SPY) 
# =========================================================================

if len(historical_dates) > 0 and not failed_due_to_margin:
    import yfinance as yf
    print("Fetching SPY benchmark...")
    spy_df = yf.download("SPY", start=str(historical_dates[0].date()), end=str(historical_dates[-1].date()), progress=False)
    spy_close = spy_df['Close'].squeeze()
    spy_close.index = pd.to_datetime(spy_close.index).tz_localize(None)

    results_df = pd.DataFrame({'Date': historical_dates, 'Agent_NAV': historical_portfolio_nav}).set_index('Date')
    
    spy_aligned = spy_close.reindex(results_df.index).ffill()
    spy_initial = spy_aligned.iloc[0]
    results_df['SPY_NAV'] = (spy_aligned / spy_initial) * INITIAL_CAPITAL
    
    results_df['Agent_Peak'] = results_df['Agent_NAV'].cummax()
    results_df['Drawdown'] = (results_df['Agent_NAV'] - results_df['Agent_Peak']) / results_df['Agent_Peak']
    
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.1, row_heights=[0.7, 0.3],
                        subplot_titles=('Rolling Tranches Portfolio NAV vs S&P 500', 'Strategy Drawdown Analysis (%)'))

    fig.add_trace(go.Scatter(x=results_df.index, y=results_df['Agent_NAV'], name='Portfolio NAV ($)', line=dict(color='indigo', width=2)), row=1, col=1)
    fig.add_trace(go.Scatter(x=results_df.index, y=results_df['SPY_NAV'], name='SPY Benchmark ($)', line=dict(color='gray', dash='dash')), row=1, col=1)
    fig.add_trace(go.Scatter(x=results_df.index, y=results_df['Drawdown']*100, name='Drawdown (%)', fill='tozeroy', line=dict(color='red', width=1)), row=2, col=1)

    fig.update_layout(title=f'Rolling Tranches Strategy (Initial: ${INITIAL_CAPITAL})', height=800, template='plotly_white')
    fig.show()

    total_return = (results_df['Agent_NAV'].iloc[-1] - INITIAL_CAPITAL) / INITIAL_CAPITAL
    
    # --- 計算經濟學指標 (Economic Metrics) ---
    results_df['Daily_Return'] = results_df['Agent_NAV'].pct_change().fillna(0)
    trading_days = len(results_df)
    years = trading_days / 252.0
    
    # 1. 年化報酬率 (CAGR)
    annualized_return = ((results_df['Agent_NAV'].iloc[-1] / INITIAL_CAPITAL) ** (1 / years) - 1) if years > 0 else 0.0
    
    # 2. 年化波動率 (Annualized Volatility)
    annualized_volatility = results_df['Daily_Return'].std() * (252 ** 0.5)
    
    # 3. 年化夏普比率 (Sharpe Ratio, 假設 Risk-Free Rate = 0)
    sharpe_ratio = (annualized_return / annualized_volatility) if annualized_volatility > 0 else 0.0
    
    # 4. 卡瑪比率 (Calmar Ratio)
    mdd = results_df['Drawdown'].min()
    calmar_ratio = (annualized_return / abs(mdd)) if mdd < 0 else 0.0
    
    print("\n📊 【滾動梯隊資金管理 - 最終總結結算】 📊")
    print(f"🏁 最終資金餘額: ${results_df['Agent_NAV'].iloc[-1]:,.2f}")
    print(f"📈 累計淨報酬率: {total_return * 100:.2f}%")
    print(f"🌍 年化報酬率 (CAGR): {annualized_return * 100:.2f}%")
    print(f"🌪 年化波動率 (Volatility): {annualized_volatility * 100:.2f}%")
    print(f"📉 最大回撤 (MDD): {results_df['Drawdown'].min() * 100:.2f}%")
    print(f"⚖️ 年化夏普比率 (Sharpe Ratio): {sharpe_ratio:.2f}")
    print(f"🛡️ 卡瑪比率 (Calmar Ratio): {calmar_ratio:.2f}")
    print(f"🔄 成功執行退歸的梯隊: {completed_tranches_count} 梯")
    print(f"🛒 全期間總交易次數: {sum(trade_frequencies)} 次\n")
# Out:
# Fetching SPY benchmark...
# ✅ 訓練結束時間: 2026-04-07 11:10:07
# ⏱️ 總共執行耗時: 0 小時 0 分 0 秒
#
# 📊 【滾動梯隊資金管理 - 最終總結結算】 📊
# 🏁 最終資金餘額: $18,844.93
# 📈 累計淨報酬率: -37.18%
# 📉 最大回撤 (MDD): -37.55%
# 🔄 成功執行退歸的梯隊: 314 梯
# 🛒 全期間總交易次數: 1630 次
