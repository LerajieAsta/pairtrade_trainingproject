# %% [raw]
# ---
# title: "結合無監督動態分群與深度強化學習之配對交易系統建構與實證：以 S&P 500 為例"
# format:
#   revealjs:
#     scrollable: true
#     smaller: true
#     slide-number: true
#     slide-level: 3
# execute:          # <--- 新增這層控制執行行為
#   echo: true      # <--- 強制整份簡報預設都要印出程式碼
# output-location: default
# ---

# %% [markdown]
# ## 1. 研究動機 (Research Motivation)
#
# 建立此基準模型（Baseline Model）的核心目的，是為了未來一年期論文中「強化學習（RL）交易模型」提供客觀、可靠的對比標竿。
#
# 在導入複雜的深度增強式學習（Deep Reinforcement Learning, DRL）之前，必須先建立穩固的基礎：
# 1. **確保資料純淨度**：妥善處理歷史數據中的生存者偏誤（Survivorship Bias），確保回測結果貼近真實市場。
# 2. **建立傳統交易邏輯底盤**：實作具備共整合（Cointegration）與 Z-Score 邏輯的傳統配對交易系統，驗證均值回歸特性的有效性，作為後續 RL 代理人學習的基礎狀態與邏輯參考。

# %% [markdown]
# ## 2. 文獻回顧 (Literature Review)
#
# 配對交易（Pairs Trading）為統計套利（Statistical Arbitrage）中經典的市場中性策略，本階段實作主要基於以下經典框架與最新研究進行建構：
#
# - **傳統配對交易框架**：參考 Gatev, Goetzmann & Rouwenhorst (2006) 提出的經典方法論。該文獻奠定了使用距離法（Sum of Squared Differences, SSD）來篩選潛在配對，並採用滾動視窗（Rolling Window）機制的業界標準。
# - **現代特徵擴展與機器學習應用**：參考 Yufei Sun (2025) 對於配對交易系統性文獻的最新整理。其研究確立了將總體經濟指標（Macroeconomic Indicators，例如 VIX）納入考量，以及後續應用機器學習進行動態分群（Clustering）的發展方向，這也成為我們後續強化學習模型的特徵工程藍圖。

# %% [markdown]
# ## 3. 資料說明與前置處理 (Data Description & Preprocessing)
#
# - **資料來源**：本研究使用 S&P 500 歷史日 K 線資料庫 (`sp500_data.db`)，資料期間涵蓋 **2000-01-01 至 2025-12-31** 的數據。
# - **資料清洗步驟**：
#     1. **前向填充與剔除稀疏股票**：針對價格序列進行前向填充（Forward-fill）最多 5 天，避免假日或停牌影響，並剔除有效交易日過少的稀疏股票。
#     2. **生存者偏誤（Survivorship Bias）處理**：確保資料庫中包含歷史已下市成分股之數據，避免回測時因只考慮現有成分股而產生高估績效的生存者偏誤。
#     3. **宏觀指標融合**：自動整合 Yahoo Finance 的 VIX 波動率指數至特徵矩陣中，為未來環境狀態空間（State Space）提供總體經濟環境的降維特徵。

# %% [markdown]
#  ## 4. 策略說明與實作細節 (Strategy Description & Implementation Details)
#
# > **策略依據**：Gatev, Goetzmann & Rouwenhorst (2006)
#
# ## 策略總覽
# 配對交易為**市場中性**的統計套利策略。
#
# | 階段 | 名稱 | 說明 |
# |:---:|------|------|
# | **1** | 初始化與資料收集 | 參數、SQLite、清理 |
# | **2** | 配對選擇 | 協整檢驗 → SSD 排序 |
# | **3** | 策略執行 | Z-Score 訊號 → PnL |
# | **4** | 績效評估 | Sharpe、MDD、CAGR |

# %% [markdown]
# ### 階段一：初始化與資料收集
# ### 1-1 套件安裝

# %%
import subprocess, sys
for pkg in ['statsmodels','plotly','ipywidgets','kaleido','yfinance']:
    subprocess.check_call([sys.executable,'-m','pip','install',pkg,'-q'])
import warnings; warnings.filterwarnings('ignore')
import sqlite3, numpy as np, pandas as pd
import logging
from itertools import combinations
from statsmodels.tsa.stattools import coint
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display, HTML
pd.set_option('display.float_format','{:.4f}'.format)
# print('套件導入完成。')
# Out:
# 套件導入完成。

# %% [markdown]
# ### 1-2 全域參數設定
#
# > **使用者只需修改此區塊，即可調整所有策略參數。**
#
# | 參數 | 預設値 | 說明 |
# |------|--------|------|
# | `DB_PATH` | `sp500_data.db` | SQLite 資料庫路徑 |
# | `FORMATION_WINDOW` | `252` | 形成期（12M）|
# | `TRADING_WINDOW` | `126` | 交易期（6M）|
# | `COINT_P_VALUE` | `0.01` | 協整檢驗顯著水準 |
# | `TOP_N_PAIRS` | `[5,20]` | Top-N 配對數 |
# | `Z_ENTRY` | `1.5` | 進場閾値 |
# | `Z_EXIT` | `0.75` | 出場閾値 |
# | `STOP_LOSS` | `3.0` | 停損改密 |
# | `TRANSACTION_COST` | `0.001` | 單邊成本 0.1% |

# %%
# ================================================================
#   Global Parameter Block  -- Edit here to tune strategy
# ================================================================
import os as _os
# DB_PATH: absolute path to the 342MB database (project root)
DB_PATH           = r'c:\Clark\YZU\Papper\Code\sp500_data.db'
START_DATE        = '2000-01-01'
END_DATE          = '2025-12-31'
FORMATION_WINDOW  = 252
TRADING_WINDOW    = 126
COINT_P_VALUE     = 0.01
TOP_N_PAIRS       = [5, 20]
Z_ENTRY           = 1.5
Z_EXIT            = 0.75
STOP_LOSS         = 3.0
TRANSACTION_COST  = 0.001
SECTOR_NEUTRAL    = True
TARGET_SECTOR     = 'All'          # 設定為All為全產業，可指定特定產業
MIN_HISTORY_DAYS  = 200
HEDGE_RATIO       = 1.0
print(f'DB     : {DB_PATH}')
print(f'DB exists: {_os.path.exists(DB_PATH)}')
print(f'DB size  : {_os.path.getsize(DB_PATH)//1024//1024} MB')
print(f'Period : {START_DATE} ~ {END_DATE}')
print(f'Windows: {FORMATION_WINDOW}d / {TRADING_WINDOW}d')
# Out:
# DB     : c:\Clark\YZU\Papper\Code\sp500_data.db
# DB exists: True
# DB size  : 342 MB
# Period : 2000-01-01 ~ 2025-12-31
# Windows: 252d / 126d

# %% [markdown]
# ### 1-3 資料讀取與清理
#
# **清理流程**: 前向填充(最多5天) → 剪除稀疏股票 → 對齊日期
#
# **資料庫結構 (`sp500_data.db`)**:
#
# | 資料表 | 關鍵欄位 |
# |--------|----------|
# | `daily_prices` | `ticker, date, adj_close` |
# | `tickers` | `ticker, sector` |

# %%
def load_data_from_db(db_path, start_date, end_date):
    """Load price and sector data from SQLite."""
    conn = sqlite3.connect(db_path)
    price_queries = [
        (f"SELECT date, ticker, adj_close AS close FROM daily_prices "
         f"WHERE date BETWEEN '{start_date}' AND '{end_date}' ORDER BY date"),
        (f"SELECT date, ticker, close FROM stock_prices "
         f"WHERE date BETWEEN '{start_date}' AND '{end_date}' ORDER BY date"),
    ]
    prices_df = None
    for q in price_queries:
        try:
            prices_df = pd.read_sql_query(q, conn, parse_dates=['date'])
            if len(prices_df) > 0:
                print(f'Price rows: {len(prices_df):,}')
                break
        except Exception:
            continue
    if prices_df is None or len(prices_df) == 0:
        tbls = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", conn)
        conn.close()
        raise RuntimeError(f"No price table. Tables: {tbls['name'].tolist()}")
    sector_queries = [
        "SELECT ticker, sector FROM tickers",
        "SELECT ticker, sector FROM sp500_components GROUP BY ticker",
    ]
    sector_df = None
    for q in sector_queries:
        try:
            sector_df = pd.read_sql_query(q, conn)
            if len(sector_df) > 0:
                print(f'Sector rows: {len(sector_df):,}')
                break
        except Exception:
            continue
    conn.close()
    if sector_df is None or len(sector_df) == 0:
        print('WARNING: No sector table, using Unknown.')
        sector_df = pd.DataFrame({'ticker': prices_df['ticker'].unique(), 'sector': 'Unknown'})
        
    # [Mod] Mitigate Survivorship Bias: Check if delisted components exist
    max_date = prices_df['date'].max()
    max_dates = prices_df.groupby('ticker')['date'].max()
    delisted_count = (max_dates < max_date - pd.Timedelta(days=30)).sum()
    if delisted_count < 10:
        import logging
        logging.warning("STRICT RESEARCH LIMITATION: Database lacks historically delisted S&P 500 components. Survivorship Bias is present.")
        
    return prices_df, sector_df


def preprocess_prices(prices_df, min_days=MIN_HISTORY_DAYS):
    """Pivot, forward-fill, drop sparse tickers."""
    pivot = prices_df.pivot_table(index='date', columns='ticker', values='close', aggfunc='last')
    pivot.index = pd.to_datetime(pivot.index)
    pivot.sort_index(inplace=True)
    pivot.ffill(limit=5, inplace=True)
    valid = pivot.columns[pivot.notna().sum() >= min_days]
    pivot = pivot[valid]
    print(f'Matrix: {len(pivot)} days x {len(pivot.columns)} tickers')

    # [Mod] Integrate Macroeconomic Indicator (VIX)
    import yfinance as yf
    print("Fetching VIX data...")
    try:
        vix_data = yf.download("^VIX", start=pivot.index.min(), end=pivot.index.max() + pd.Timedelta(days=1), progress=False)
        if isinstance(vix_data.columns, pd.MultiIndex):
            vix_close = vix_data['Close'].squeeze()
        else:
            vix_close = vix_data['Close']
        vix_df = pd.DataFrame({'VIX': vix_close})
        vix_df.index = pd.to_datetime(vix_df.index).tz_localize(None)
        vix_aligned = vix_df.reindex(pivot.index).ffill()
        print("VIX feature matrix aligned.")
    except Exception as e:
        print(f"Error fetching VIX: {e}")
        vix_aligned = pd.DataFrame(index=pivot.index, columns=['VIX'])

    return pivot, vix_aligned

# %%
prices_raw, sector_info = load_data_from_db(DB_PATH, START_DATE, END_DATE)
price_pivot, vix_features = preprocess_prices(prices_raw)
sector_map  = sector_info.set_index('ticker')['sector'].to_dict()
display(price_pivot.iloc[:3, :6])
print(pd.Series(sector_map).value_counts().head(10))
# Out:
# Price rows: 3,607,121
# Sector rows: 843
# Matrix: 6539 days x 660 tickers
# Fetching VIX data...
# VIX feature matrix aligned.
# ticker           A      AA  AAL  AAP   AAPL  ABBV
# date
# 2000-01-03 43.0364 68.8711  NaN  NaN 0.8385   NaN
# 2000-01-04 39.7489 69.1902  NaN  NaN 0.7678   NaN
# 2000-01-05 37.2833 73.1788  NaN  NaN 0.7790   NaN
# Unknown                   340
# Industrials                79
# Financials                 76
# Information Technology     71
# Health Care                60
# Consumer Discretionary     48
# Consumer Staples           36
# Utilities                  31
# Real Estate                31
# Materials                  26
# Name: count, dtype: int64

# %% [markdown]
# ### 階段二：配對選擇（形成期）
#
# **Engle-Granger 協整檢驗**：
# $$P_{A,t} = \\alpha + \\beta P_{B,t} + \\varepsilon_t$$
# 如果殘差 $\\varepsilon_t$ 的 ADF $p < 0.01$，則判定協整。
#
# **SSD 排序**: $\\text{SSD}(A,B)=\\sum(r_A^{norm}-r_B^{norm})^2$
#
# SSD 越小 → 狸圖越相似 → 優先選入交易期。
#
# **選定流程**: 同產業候選 → 協整檢驗 ($p<0.01$) → SSD由小到大排序 → Top-N

# %%
def normalize_prices(prices):
    return prices / prices.iloc[0]

def compute_ssd(na, nb):
    return ((na - nb) ** 2).sum()

def select_pairs_for_window(price_window, sector_map, top_ns,
                            coint_pval=COINT_P_VALUE,
                            sector_neutral=SECTOR_NEUTRAL,
                            target_sector=TARGET_SECTOR):
    """Cointegration + SSD ranking for one formation window."""
    norm  = normalize_prices(price_window.dropna(axis=1))
    valid = norm.columns.tolist()
    
    # [Mod] Scope Management: Target Sector Filtering
    if target_sector is not None and target_sector != 'All':
        valid = [t for t in valid if sector_map.get(t, 'Unknown') == target_sector]
        print(f'  Filtered by target sector ({target_sector}): {len(valid)} candidates remaining.')
        candidates = [(a,b,target_sector) for a,b in combinations(valid,2)]
    elif sector_neutral:
        groups = {}
        for t in valid:
            groups.setdefault(sector_map.get(t,'Unknown'),[]).append(t)
        candidates = [(a,b,s) for s,ms in groups.items()
                      if len(ms)>=2 for a,b in combinations(ms,2)]
    else:
        candidates = [(a,b,'All') for a,b in combinations(valid,2)]
    print(f'  Candidates: {len(candidates):,}')
    passed = []
    for a,b,sector in candidates:
        try:
            sa = price_window[a].dropna()
            sb = price_window[b].dropna()
            idx = sa.index.intersection(sb.index)
            if len(idx) < FORMATION_WINDOW*0.8: continue
            _,pval,_ = coint(sa[idx].values, sb[idx].values)
            if pval < coint_pval:
                ssd = compute_ssd(norm[a], norm[b])
                passed.append({'stock_a':a,'stock_b':b,'sector':sector,'coint_p':pval,'ssd':ssd})
        except Exception:
            continue
    print(f'  Passed coint: {len(passed):,}')
    if not passed:
        return {n:[] for n in top_ns}
    df = pd.DataFrame(passed).sort_values('ssd')
    return {n: df.head(n).to_dict('records') for n in top_ns}

# %% [markdown]
# ### 階段三：策略執行（交易期）
#
# $$Z_t = (\\text{spread}_t - \\mu_{hist})/\\sigma_{hist}$$
#
# | 訊號 | 操作 |
# |------|---------|
# | $Z > +1.5$ | 放空A、做多B |
# | $Z < -1.5$ | 做多A、放空B |
# | $|Z| < 0.75$ | 平倉 |
# | $|Z| > 3.0$ | 停損平倉 |
#
# **跨日執行法 (Wait-One-Day)**: 訊號後隔日執行，避免 bid-ask bounce。
# **Dollar-Neutral**: 每配對 $1 做多 + $1 放空。

# %%
def execute_pair_trades(trade_prices, pair, form_prices,
                        z_entry=Z_ENTRY, z_exit=Z_EXIT,
                        stop_loss=STOP_LOSS, cost=TRANSACTION_COST,
                        hedge_ratio=HEDGE_RATIO):
    """Dollar-neutral pair trade with wait-one-day rule."""
    a, b = pair['stock_a'], pair['stock_b']
    try:
        pa_t = trade_prices[a].dropna()
        pb_t = trade_prices[b].dropna()
        pa_f = form_prices[a].dropna()
        pb_f = form_prices[b].dropna()
    except KeyError:
        return pd.Series(0.0, index=trade_prices.index)
    common = pa_t.index.intersection(pb_t.index)
    if len(common) < 5:
        return pd.Series(0.0, index=trade_prices.index)
    na = pa_t[common] / pa_f.iloc[-1]
    nb = pb_t[common] / pb_f.iloc[-1]
    fi = pa_f.index.intersection(pb_f.index)
    fs = (pa_f[fi]/pa_f[fi].iloc[0]) - (pb_f[fi]/pb_f[fi].iloc[0])
    mu, sd = fs.mean(), fs.std()
    if sd < 1e-8:
        return pd.Series(0.0, index=trade_prices.index)
    z = ((na - nb) - mu) / sd
    pos, pnl_d = 0, {}
    pna, pnb = na.iloc[0], nb.iloc[0]
    for i, dt in enumerate(common):
        zi, cna, cnb = z.iloc[i], na.iloc[i], nb.iloc[i]
        p = 0.0
        if i > 0 and pos != 0:
            # [Mod] Application of hedge_ratio to position sizing
            p = pos * ((cna-pna)/pna - hedge_ratio * (cnb-pnb)/pnb)
        new = pos
        if pos == 0:
            if   zi >  z_entry: new = -1; p -= 2 * cost * (1 + hedge_ratio)
            elif zi < -z_entry: new = +1; p -= 2 * cost * (1 + hedge_ratio)
        elif abs(zi) < z_exit or abs(zi) > stop_loss:
            p -= 2 * cost * (1 + hedge_ratio); new = 0
        pos, pna, pnb = new, cna, cnb
        pnl_d[dt] = p
    return pd.Series(pnl_d, dtype=float).reindex(trade_prices.index, fill_value=0.0)

# %% [markdown]
# ### 滞動視窗主迴圈
#
# ```
# 視窗 0: 形成期 [Day 0..251]  | 交易期 [Day 252..377]
# 視窗 1: 形成期 [Day 126..377] | 交易期 [Day 378..503]
# (每次向前滞動 TRADING_WINDOW 個交易日)
# ```

# %%
def run_backtesting(price_pivot, sector_map,
                    formation_window=FORMATION_WINDOW,
                    trading_window=TRADING_WINDOW,
                    top_ns=TOP_N_PAIRS):
    """Main rolling-window backtest loop."""
    dates = price_pivot.index
    N     = len(dates)
    all_pnl = {n: pd.DataFrame(index=dates) for n in top_ns}
    records = []
    si, wid = 0, 0
    while si + formation_window + trading_window <= N:
        fe = si + formation_window
        te = fe + trading_window
        print(f'Window {wid:02d}  Form:{dates[si].date()}-{dates[fe-1].date()}  '
              f'Trade:{dates[fe].date()}-{dates[te-1].date()}')
        fp  = price_pivot.iloc[si:fe]
        tp  = price_pivot.iloc[fe:te]
        sel = select_pairs_for_window(fp, sector_map, top_ns)
        rec = {'window_id':wid,'form_start':dates[si],'form_end':dates[fe-1],
               'trade_start':dates[fe],'trade_end':dates[te-1],'pairs_by_n':sel}
        records.append(rec)
        for n in top_ns:
            pairs = sel.get(n,[])
            col   = f'W{wid:02d}'
            wpnl  = pd.Series(0.0, index=dates)
            if pairs:
                for p in pairs:
                    wpnl = wpnl.add(execute_pair_trades(tp,p,fp)/len(pairs))
            all_pnl[n][col] = wpnl
        si += trading_window; wid += 1
    print(f'Backtest done: {wid} windows.')
    return all_pnl, records

print('Starting backtest...')
all_pnl, window_records = run_backtesting(price_pivot, sector_map)
# Out:
# Starting backtest...
# Window 00  Form:2000-01-03-2000-12-29  Trade:2001-01-02-2001-07-02
#   Candidates: 9,739
#   Passed coint: 394
# Window 01  Form:2000-07-03-2001-07-02  Trade:2001-07-03-2002-01-07
#   Candidates: 10,064
#   Passed coint: 297
# Window 02  Form:2001-01-02-2002-01-07  Trade:2002-01-08-2002-07-09
#   Candidates: 10,401
#   Passed coint: 436
# Window 03  Form:2001-07-03-2002-07-09  Trade:2002-07-10-2003-01-07
#   Candidates: 10,771
#   Passed coint: 311
# Window 04  Form:2002-01-08-2003-01-07  Trade:2003-01-08-2003-07-09
#   Candidates: 11,269
#   Passed coint: 317
# Window 05  Form:2002-07-10-2003-07-09  Trade:2003-07-10-2004-01-07
#   Candidates: 11,510
#   Passed coint: 447
# Window 06  Form:2003-01-08-2004-01-07  Trade:2004-01-08-2004-07-09
#   Candidates: 11,645
#   Passed coint: 370
# Window 07  Form:2003-07-10-2004-07-09  Trade:2004-07-12-2005-01-06
#   Candidates: 11,785
#   Passed coint: 213
# Window 08  Form:2004-01-08-2005-01-06  Trade:2005-01-07-2005-07-08
#   Candidates: 11,903
#   Passed coint: 346
# Window 09  Form:2004-07-12-2005-07-08  Trade:2005-07-11-2006-01-06
#   Candidates: 12,218
#   Passed coint: 358
# Window 10  Form:2005-01-07-2006-01-06  Trade:2006-01-09-2006-07-10
#   Candidates: 12,411
#   Passed coint: 270
# Window 11  Form:2005-07-11-2006-07-10  Trade:2006-07-11-2007-01-09
#   Candidates: 12,627
#   Passed coint: 327
# Window 12  Form:2006-01-09-2007-01-09  Trade:2007-01-10-2007-07-11
#   Candidates: 13,115
#   Passed coint: 203
# Window 13  Form:2006-07-11-2007-07-11  Trade:2007-07-12-2008-01-09
#   Candidates: 13,333
#   Passed coint: 277
# Window 14  Form:2007-01-10-2008-01-09  Trade:2008-01-10-2008-07-10
#   Candidates: 13,741
#   Passed coint: 405
# Window 15  Form:2007-07-12-2008-07-10  Trade:2008-07-11-2009-01-08
#   Candidates: 14,159
#   Passed coint: 392
# Window 16  Form:2008-01-10-2009-01-08  Trade:2009-01-09-2009-07-10
#   Candidates: 14,400
#   Passed coint: 548
# Window 17  Form:2008-07-11-2009-07-10  Trade:2009-07-13-2010-01-08
#   Candidates: 14,676
#   Passed coint: 922
# Window 18  Form:2009-01-09-2010-01-08  Trade:2010-01-11-2010-07-12
#   Candidates: 14,676
#   Passed coint: 795
# Window 19  Form:2009-07-13-2010-07-12  Trade:2010-07-13-2011-01-07
#   Candidates: 14,676
#   Passed coint: 305
# Window 20  Form:2010-01-11-2011-01-07  Trade:2011-01-10-2011-07-11
#   Candidates: 14,997
#   Passed coint: 259
# Window 21  Form:2010-07-13-2011-07-11  Trade:2011-07-12-2012-01-09
#   Candidates: 15,399
#   Passed coint: 343
# Window 22  Form:2011-01-10-2012-01-09  Trade:2012-01-10-2012-07-10
#   Candidates: 15,749
#   Passed coint: 530
# Window 23  Form:2011-07-12-2012-07-10  Trade:2012-07-11-2013-01-10
#   Candidates: 15,972
#   Passed coint: 674
# Window 24  Form:2012-01-10-2013-01-10  Trade:2013-01-11-2013-07-12
#   Candidates: 16,406
#   Passed coint: 213
# Window 25  Form:2012-07-11-2013-07-12  Trade:2013-07-15-2014-01-10
#   Candidates: 16,909
#   Passed coint: 433
# Window 26  Form:2013-01-11-2014-01-10  Trade:2014-01-13-2014-07-14
#   Candidates: 17,098
#   Passed coint: 349
# Window 27  Form:2013-07-15-2014-07-14  Trade:2014-07-15-2015-01-12
#   Candidates: 17,461
#   Passed coint: 448
# Window 28  Form:2014-01-13-2015-01-12  Trade:2015-01-13-2015-07-14
#   Candidates: 17,688
#   Passed coint: 496
# Window 29  Form:2014-07-15-2015-07-14  Trade:2015-07-15-2016-01-12
#   Candidates: 18,002
#   Passed coint: 503
# Window 30  Form:2015-01-13-2016-01-12  Trade:2016-01-13-2016-07-13
#   Candidates: 18,437
#   Passed coint: 431
# Window 31  Form:2015-07-15-2016-07-13  Trade:2016-07-14-2017-01-11
#   Candidates: 18,841
#   Passed coint: 491
# Window 32  Form:2016-01-13-2017-01-11  Trade:2017-01-12-2017-07-13
#   Candidates: 19,712
#   Passed coint: 570
# Window 33  Form:2016-07-14-2017-07-13  Trade:2017-07-14-2018-01-11
#   Candidates: 19,658
#   Passed coint: 478
# Window 34  Form:2017-01-12-2018-01-11  Trade:2018-01-12-2018-07-13
#   Candidates: 19,753
#   Passed coint: 368
# Window 35  Form:2017-07-14-2018-07-13  Trade:2018-07-16-2019-01-14
#   Candidates: 19,414
#   Passed coint: 344
# Window 36  Form:2018-01-12-2019-01-14  Trade:2019-01-15-2019-07-16
#   Candidates: 18,859
#   Passed coint: 538
# Window 37  Form:2018-07-16-2019-07-16  Trade:2019-07-17-2020-01-14
#   Candidates: 18,745
#   Passed coint: 321
# Window 38  Form:2019-01-15-2020-01-14  Trade:2020-01-15-2020-07-15
#   Candidates: 18,802
#   Passed coint: 391
# Window 39  Form:2019-07-17-2020-07-15  Trade:2020-07-16-2021-01-13
#   Candidates: 19,147
#   Passed coint: 442
# Window 40  Form:2020-01-15-2021-01-13  Trade:2021-01-14-2021-07-15
#   Candidates: 19,328
#   Passed coint: 290
# Window 41  Form:2020-07-16-2021-07-15  Trade:2021-07-16-2022-01-12
#   Candidates: 19,830
#   Passed coint: 456
# Window 42  Form:2021-01-14-2022-01-12  Trade:2022-01-13-2022-07-15
#   Candidates: 20,229
#   Passed coint: 532
# Window 43  Form:2021-07-16-2022-07-15  Trade:2022-07-18-2023-01-13
#   Candidates: 20,513
#   Passed coint: 342
# Window 44  Form:2022-01-13-2023-01-13  Trade:2023-01-17-2023-07-18
#   Candidates: 20,710
#   Passed coint: 434
# Window 45  Form:2022-07-18-2023-07-18  Trade:2023-07-19-2024-01-17
#   Candidates: 20,863
#   Passed coint: 263
# Window 46  Form:2023-01-17-2024-01-17  Trade:2024-01-18-2024-07-18
#   Candidates: 21,045
#   Passed coint: 216
# Window 47  Form:2023-07-19-2024-07-18  Trade:2024-07-19-2025-01-17
#   Candidates: 21,205
#   Passed coint: 391
# Window 48  Form:2024-01-18-2025-01-17  Trade:2025-01-21-2025-07-22
#   Candidates: 21,535
#   Passed coint: 463
# Backtest done: 49 windows.

# %% [markdown]
# ### 階段四：績效評估與對比分析
#
# | 指標 | 公式 |
# |------|------|
# | **CAGR** | $(1+r_{total})^{252/T}-1$ |
# | **Sharpe** | $\\mu_{ann}/\\sigma_{ann}$ |
# | **MDD** | $\\max(1-NAV_t/peak_t)$ |
# | **Sortino** | 使用下行標準差 |

# %%
def compute_metrics(ret, label=''):
    """Annualised performance metrics from daily return series."""
    r = ret.dropna().replace([np.inf,-np.inf], np.nan).dropna()
    T = len(r)
    if T == 0: return {}
    cum    = (1+r).cumprod()
    tot    = cum.iloc[-1]-1
    cagr   = (1+tot)**(252/T)-1
    vol    = r.std()*np.sqrt(252)
    sharpe = (r.mean()*252)/vol if vol>0 else np.nan
    mdd    = ((cum-cum.cummax())/cum.cummax()).min()
    dn     = r[r<0].std()*np.sqrt(252)
    sortino= (r.mean()*252)/dn if dn>0 else np.nan
    return {'策略':label,'CAGR(%)':round(cagr*100,2),
            '年化波動(%)':round(vol*100,2),
            'Sharpe':round(sharpe,3) if not np.isnan(sharpe) else np.nan,
            'Sortino':round(sortino,3) if not np.isnan(sortino) else np.nan,
            '最大回撤(%)':round(mdd*100,2),
            '勝率(%)':round((r>0).mean()*100,2),
            '總報酬(%)':round(tot*100,2)}

strat_ret = {}
for n in TOP_N_PAIRS:
    df = all_pnl[n]
    if df.empty: continue
    combined = df.sum(axis=1)
    aw = (df!=0).any(axis=0).sum()
    if aw>0: combined /= aw
    strat_ret[f'Top-{n}'] = combined
strat_ret['S&P500(EW)'] = price_pivot.pct_change().mean(axis=1)

metrics_df = pd.DataFrame(
    [m for lbl,r in strat_ret.items() for m in [compute_metrics(r,lbl)] if m]
).set_index('策略')
display(metrics_df.style.background_gradient(cmap='RdYlGn',axis=0))
# Out:
# <style type="text/css">
# #T_f431a_row0_col0, #T_f431a_row0_col6, #T_f431a_row1_col0, #T_f431a_row1_col6, #T_f431a_row2_col0, #T_f431a_row2_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f431a_row0_col1, #T_f431a_row0_col3, #T_f431a_row1_col1, #T_f431a_row1_col2, #T_f431a_row1_col3, #T_f431a_row1_col5, #T_f431a_row2_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f431a_row0_col2 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_f431a_row0_col4 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_f431a_row0_col5 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_f431a_row1_col4, #T_f431a_row2_col1, #T_f431a_row2_col2, #T_f431a_row2_col3, #T_f431a_row2_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f431a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f431a_level0_col0" class="col_heading level0 col0" >CAGR(%)</th>
#       <th id="T_f431a_level0_col1" class="col_heading level0 col1" >年化波動(%)</th>
#       <th id="T_f431a_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_f431a_level0_col3" class="col_heading level0 col3" >Sortino</th>
#       <th id="T_f431a_level0_col4" class="col_heading level0 col4" >最大回撤(%)</th>
#       <th id="T_f431a_level0_col5" class="col_heading level0 col5" >勝率(%)</th>
#       <th id="T_f431a_level0_col6" class="col_heading level0 col6" >總報酬(%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >策略</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f431a_level0_row0" class="row_heading level0 row0" >Top-5</th>
#       <td id="T_f431a_row0_col0" class="data row0 col0" >-0.710000</td>
#       <td id="T_f431a_row0_col1" class="data row0 col1" >0.130000</td>
#       <td id="T_f431a_row0_col2" class="data row0 col2" >-5.483000</td>
#       <td id="T_f431a_row0_col3" class="data row0 col3" >-7.105000</td>
#       <td id="T_f431a_row0_col4" class="data row0 col4" >-17.140000</td>
#       <td id="T_f431a_row0_col5" class="data row0 col5" >26.990000</td>
#       <td id="T_f431a_row0_col6" class="data row0 col6" >-16.890000</td>
#     </tr>
#     <tr>
#       <th id="T_f431a_level0_row1" class="row_heading level0 row1" >Top-20</th>
#       <td id="T_f431a_row1_col0" class="data row1 col0" >-0.680000</td>
#       <td id="T_f431a_row1_col1" class="data row1 col1" >0.100000</td>
#       <td id="T_f431a_row1_col2" class="data row1 col2" >-7.052000</td>
#       <td id="T_f431a_row1_col3" class="data row1 col3" >-9.619000</td>
#       <td id="T_f431a_row1_col4" class="data row1 col4" >-16.280000</td>
#       <td id="T_f431a_row1_col5" class="data row1 col5" >25.250000</td>
#       <td id="T_f431a_row1_col6" class="data row1 col6" >-16.270000</td>
#     </tr>
#     <tr>
#       <th id="T_f431a_level0_row2" class="row_heading level0 row2" >S&P500(EW)</th>
#       <td id="T_f431a_row2_col0" class="data row2 col0" >inf</td>
#       <td id="T_f431a_row2_col1" class="data row2 col1" >7884.160000</td>
#       <td id="T_f431a_row2_col2" class="data row2 col2" >2.450000</td>
#       <td id="T_f431a_row2_col3" class="data row2 col3" >1202.526000</td>
#       <td id="T_f431a_row2_col4" class="data row2 col4" >-34.610000</td>
#       <td id="T_f431a_row2_col5" class="data row2 col5" >58.170000</td>
#       <td id="T_f431a_row2_col6" class="data row2 col6" >inf</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 累積 NAV 曲線與回撤圖

# %%
COLORS = px.colors.qualitative.Plotly
fig_p = make_subplots(rows=2,cols=1,shared_xaxes=True,
    row_heights=[0.65,0.35],
    subplot_titles=['累積淨値（NAV）曲線','歷史回撤（Drawdown%）'],
    vertical_spacing=0.08)
for i,(lbl,ret) in enumerate(strat_ret.items()):
    r=ret.dropna(); nav=(1+r).cumprod()
    dd=((nav-nav.cummax())/nav.cummax())*100
    c=COLORS[i%len(COLORS)]
    fig_p.add_trace(go.Scatter(x=nav.index,y=nav.values,name=lbl,
        line=dict(color=c,width=2),
        hovertemplate=f'%{{x|%Y-%m-%d}}<br>NAV:%{{y:.4f}}<extra>{lbl}</extra>'),row=1,col=1)
    fig_p.add_trace(go.Scatter(x=dd.index,y=dd.values,name=lbl,showlegend=False,
        fill='tozeroy',line=dict(color=c,width=1),
        hovertemplate=f'%{{x|%Y-%m-%d}}<br>DD:%{{y:.2f}}%<extra>{lbl}</extra>'),row=2,col=1)
fig_p.update_layout(title='配對交易策略績效對比',height=650,template='plotly_dark',
    hovermode='x unified',legend=dict(orientation='h',y=1.02,x=1,xanchor='right'))
fig_p.show()

# %% [markdown]
# ### Top-5 vs Top-20 統計表（仿 Gatev 2006）

# %%
rows_d=[]
for rec in window_records:
    wid=rec['window_id']; col=f'W{wid:02d}'
    row={'視窗':wid,'形成期起':rec['form_start'].date(),'形成期迦':rec['form_end'].date(),
         '交易期起':rec['trade_start'].date(),'交易期迦':rec['trade_end'].date()}
    for n in TOP_N_PAIRS:
        df=all_pnl.get(n,pd.DataFrame())
        if col in df.columns:
            row[f'Top-{n}報酬(%)'] = round(df[col].sum()*100,4)
            row[f'Top-{n}配對數'] = len(rec['pairs_by_n'].get(n,[]))
    row['Top-5配對'] = ', '.join(f"{p['stock_a']}/{p['stock_b']}" for p in rec['pairs_by_n'].get(5,[])[:5])
    rows_d.append(row)
cmp_df = pd.DataFrame([compute_metrics(strat_ret.get(f'Top-{n}',pd.Series()),f'Top-{n}') for n in TOP_N_PAIRS]).set_index('策略')
print('\n=== Top-N Portfolio Comparison ===')
display(cmp_df)
display(pd.DataFrame(rows_d))
# Out:
# === Top-N Portfolio Comparison ===
#         CAGR(%)  年化波動(%)  Sharpe  Sortino  最大回撤(%)   勝率(%)   總報酬(%)
# 策略
# Top-5   -0.7100   0.1300 -5.4830  -7.1050 -17.1400 26.9900 -16.8900
# Top-20  -0.6800   0.1000 -7.0520  -9.6190 -16.2800 25.2500 -16.2700
#     視窗        形成期起        形成期迦        交易期起        交易期迦  Top-5報酬(%)  Top-5配對數  \
# 0    0  2000-01-03  2000-12-29  2001-01-02  2001-07-02     -6.3941         5
# 1    1  2000-07-03  2001-07-02  2001-07-03  2002-01-07     14.6736         5
# 2    2  2001-01-02  2002-01-07  2002-01-08  2002-07-09    -25.6674         5
# 3    3  2001-07-03  2002-07-09  2002-07-10  2003-01-07    -37.9774         5
# 4    4  2002-01-08  2003-01-07  2003-01-08  2003-07-09     -9.6284         5
# 5    5  2002-07-10  2003-07-09  2003-07-10  2004-01-07    -10.0097         5
# 6    6  2003-01-08  2004-01-07  2004-01-08  2004-07-09    -42.4404         5
# 7    7  2003-07-10  2004-07-09  2004-07-12  2005-01-06    -19.3777         5
# 8    8  2004-01-08  2005-01-06  2005-01-07  2005-07-08    -10.1605         5
# 9    9  2004-07-12  2005-07-08  2005-07-11  2006-01-06     -5.1809         5
# 10  10  2005-01-07  2006-01-06  2006-01-09  2006-07-10     -0.2607         5
# 11  11  2005-07-11  2006-07-10  2006-07-11  2007-01-09     -6.3495         5
# 12  12  2006-01-09  2007-01-09  2007-01-10  2007-07-11    -18.6617         5
# 13  13  2006-07-11  2007-07-11  2007-07-12  2008-01-09    -31.7155         5
# 14  14  2007-01-10  2008-01-09  2008-01-10  2008-07-10    -19.4075         5
# 15  15  2007-07-12  2008-07-10  2008-07-11  2009-01-08    -28.8147         5
# 16  16  2008-01-10  2009-01-08  2009-01-09  2009-07-10    -19.5926         5
# 17  17  2008-07-11  2009-07-10  2009-07-13  2010-01-08    -28.6394         5
# 18  18  2009-01-09  2010-01-08  2010-01-11  2010-07-12    -15.7478         5
# 19  19  2009-07-13  2010-07-12  2010-07-13  2011-01-07    -23.7363         5
# 20  20  2010-01-11  2011-01-07  2011-01-10  2011-07-11     -0.9655         5
# 21  21  2010-07-13  2011-07-11  2011-07-12  2012-01-09    -20.0491         5
# 22  22  2011-01-10  2012-01-09  2012-01-10  2012-07-10    -15.5286         5
# 23  23  2011-07-12  2012-07-10  2012-07-11  2013-01-10    -26.6921         5
# 24  24  2012-01-10  2013-01-10  2013-01-11  2013-07-12    -30.4613         5
# 25  25  2012-07-11  2013-07-12  2013-07-15  2014-01-10    -23.2476         5
# 26  26  2013-01-11  2014-01-10  2014-01-13  2014-07-14    -30.0052         5
# 27  27  2013-07-15  2014-07-14  2014-07-15  2015-01-12     -9.5514         5
# 28  28  2014-01-13  2015-01-12  2015-01-13  2015-07-14     -5.8074         5
# 29  29  2014-07-15  2015-07-14  2015-07-15  2016-01-12    -15.7650         5
# 30  30  2015-01-13  2016-01-12  2016-01-13  2016-07-13    -30.5838         5
# 31  31  2015-07-15  2016-07-13  2016-07-14  2017-01-11    -18.5858         5
# 32  32  2016-01-13  2017-01-11  2017-01-12  2017-07-13    -28.1542         5
# 33  33  2016-07-14  2017-07-13  2017-07-14  2018-01-11    -21.8678         5
# 34  34  2017-01-12  2018-01-11  2018-01-12  2018-07-13    -14.7121         5
# 35  35  2017-07-14  2018-07-13  2018-07-16  2019-01-14    -14.9402         5
# 36  36  2018-01-12  2019-01-14  2019-01-15  2019-07-16    -24.3587         5
# 37  37  2018-07-16  2019-07-16  2019-07-17  2020-01-14    -20.6916         5
# 38  38  2019-01-15  2020-01-14  2020-01-15  2020-07-15    -21.7691         5
# 39  39  2019-07-17  2020-07-15  2020-07-16  2021-01-13     -9.5501         5
# 40  40  2020-01-15  2021-01-13  2021-01-14  2021-07-15    -15.1322         5
# 41  41  2020-07-16  2021-07-15  2021-07-16  2022-01-12    -14.7627         5
# 42  42  2021-01-14  2022-01-12  2022-01-13  2022-07-15    -15.1645         5
# 43  43  2021-07-16  2022-07-15  2022-07-18  2023-01-13    -29.4665         5
# 44  44  2022-01-13  2023-01-13  2023-01-17  2023-07-18    -32.5465         5
# 45  45  2022-07-18  2023-07-18  2023-07-19  2024-01-17    -11.5267         5
# 46  46  2023-01-17  2024-01-17  2024-01-18  2024-07-18    -22.0808         5
# 47  47  2023-07-19  2024-07-18  2024-07-19  2025-01-17    -25.5841         5
# 48  48  2024-01-18  2025-01-17  2025-01-21  2025-07-22    -12.0153         5
#
#     Top-20報酬(%)  Top-20配對數                                           Top-5配對
# 0      -14.3212         20       AVB/BXP, ARE/CPT, ARE/REG, ITW/UPS, PLD/REG
# 1       -0.3191         20       HUBB/ITW, ARE/EQR, BF-B/KR, AFL/CB, BWA/SIG
# 2      -21.1682         20       ARE/KIM, ARE/REG, D/DUK, NDSN/UPS, AXP/NTRS
# 3      -22.7682         20         ES/PEG, HIG/SPGI, ARE/O, ARE/SPG, CVX/TPL
# 4      -13.0933         20      HBAN/MTB, DTE/ETR, APD/PKG, KEY/MTB, CPT/EQR
# 5      -13.7371         20      CPT/EQR, FRT/KIM, UNP/UPS, EXC/NEE, HBAN/PFG
# 6      -25.1031         20   HBAN/MTB, FRT/SPG, EMR/ITW, HBAN/SPGI, MTB/SPGI
# 7      -14.3084         20              NEE/SO, C/EG, CLX/PG, KIM/REG, NI/SO
# 8      -13.6458         20        BXP/KIM, AEP/ATO, NI/XEL, FRT/REG, BXP/REG
# 9       -5.6367         20        ARE/KIM, FRT/SPG, CCL/NKE, BAC/KEY, KO/TSN
# 10      -7.4319         20    GOOG/GOOGL, EQR/ESS, AVB/MAA, GL/JPM, AXP/SPGI
# 11     -13.3182         20    GOOG/GOOGL, MTB/WFC, USB/WFC, EQR/MAA, EQR/FRT
# 12     -16.8752         20   GOOG/GOOGL, FISV/TRV, AME/MMM, LNC/NWL, EMR/HON
# 13     -28.2382         20    GOOG/GOOGL, AIZ/CB, MKC/PG, HPQ/IBM, AJG/BRK-B
# 14     -24.8109         20   GOOG/GOOGL, CMS/CNP, AJG/WFC, ACGL/EG, VTR/WELL
# 15     -27.4483         20      GOOG/GOOGL, DUK/XEL, EQR/UDR, D/PPL, AEP/LNT
# 16      -7.8980         20  GOOG/GOOGL, EVRG/XEL, ATO/WEC, HUBB/RTX, AEE/AEP
# 17     -23.7114         20    GOOG/GOOGL, AVB/CPT, BKR/HAL, CBE/TWX, PNR/SWK
# 18      -7.6092         20     GOOG/GOOGL, EIX/EVRG, AEP/ES, AWK/ES, AEP/AWK
# 19     -19.0925         20    GOOG/GOOGL, CMS/PNW, CMS/CNP, AJG/WRB, BDX/JNJ
# 20     -21.6468         20     GOOG/GOOGL, EVRG/SO, DUK/ED, LNT/NI, EVRG/LNT
# 21     -14.0493         20      GOOG/GOOGL, SO/WEC, DUK/PNW, DUK/ED, WEC/XEL
# 22     -13.2387         20    GOOG/GOOGL, LNT/PNW, CMS/XEL, KIM/REG, ARE/KIM
# 23     -20.3909         20     GOOG/GOOGL, AVB/ESS, DUK/SO, PNW/XEL, CAH/COR
# 24     -20.3811         20    GOOG/GOOGL, AVB/MAA, PEG/XEL, AVB/ESS, ATO/PNW
# 25     -12.5905         20     GOOG/GOOGL, D/EVRG, IEX/PCAR, AXP/GL, MET/PRU
# 26     -18.0491         20   GOOG/GOOGL, DTE/WEC, BF-B/WMT, AMT/WY, HON/PAYX
# 27     -18.0846         20        PG/WMT, CMS/XEL, AWK/LNT, ESS/UDR, ESS/MAA
# 28     -10.0038         20        CMS/XEL, ITW/MMM, AEP/PCG, DUK/ED, JPM/RJF
# 29     -15.5325         20         ES/WEC, ATO/NEE, HSY/WMT, PNW/WEC, ES/PNW
# 30     -27.6861         20         CMS/XEL, AEP/SO, EQR/FRT, ES/PCG, AJG/STT
# 31     -22.5907         20        CMS/XEL, AON/BRO, CME/L, ALLE/CTAS, BK/MTB
# 32     -16.4370         20      DUK/ED, CMS/XEL, BAC/CFG, EXPD/UPS, PFE/RVTY
# 33     -24.5004         20        CMS/PPL, CMS/XEL, CMS/LNT, AEP/ED, ATO/PPL
# 34     -21.9407         20       PNW/SRE, MS/PNC, JNJ/SYK, MCO/MSCI, ROK/SWK
# 35     -13.3035         20    NWS/NWSA, DTE/XEL, COST/SYY, DLR/MAA, FITB/JPM
# 36     -21.8359         20       CPT/MAA, AEP/XEL, AEP/DUK, AWK/CMS, ARE/BXP
# 37     -28.2203         20            CMS/FE, ATO/LNT, DTE/FE, ED/NI, CB/FIS
# 38     -19.4051         20        NWS/NWSA, UA/UAA, NEE/SO, CBOE/ICE, RF/WFC
# 39     -12.7919         20         NWS/NWSA, RF/TFC, FIS/MA, NI/PNW, MA/MRSH
# 40     -12.4481         20      DHR/TMO, AZO/ORLY, IEX/UNP, AEP/PNW, DOV/SNA
# 41     -16.3293         20       AMGN/BAX, ROP/VRSN, LHX/WM, PEG/SO, IEX/UNP
# 42     -22.2709         20            AFL/BRK-B, D/WEC, AME/ITW, D/SO, EME/J
# 43     -24.5649         20  ACGL/CB, GOOG/GOOGL, AEE/ETR, JCI/ROK, NDAQ/SPGI
# 44     -28.2974         20   GOOG/GOOGL, NWS/NWSA, CPT/UDR, NTRS/USB, HD/NVR
# 45     -18.0909         20     SYF/WFC, PAYX/UNP, INCY/WAT, CE/QRVO, ICE/MCO
# 46     -15.7601         20     CNP/LNT, MCO/SPGI, EXPD/SNA, AOS/FAST, EW/ZBH
# 47     -24.9627         20     CMS/FE, CTRA/EXE, BRK-B/CINF, CMS/PPL, FE/PPL
# 48     -13.8745         20     CPT/EQR, CINF/NDAQ, KEY/RF, AJG/MCO, NDAQ/PNC
